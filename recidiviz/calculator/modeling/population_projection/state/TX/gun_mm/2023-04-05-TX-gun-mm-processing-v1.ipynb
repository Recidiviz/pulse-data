# %%
"""
STATE: AL
POLICY: Parole Grant Rates
VERSION: V1
DATA SOURCE: Public AL reports
DATA QUALITY: medium-low
HIGHEST PRIORITY MISSING DATA: N/A
REFERENCE_DATE: October 2022
TIME_STEP: Month
ADDITIONAL NOTES: Initial policy scoping doc https://docs.google.com/document/d/1mj6Fmm3aCmx08PqhNShV6Rb8MCRuHQ2D56BmxeJKxKg/edit?usp=sharing
"""

import logging
import pandas as pd
import numpy as np
import pdb
import matplotlib as plt
from IPython.display import display
import itertools


# %run /Users/jazz/Recidiviz/recidiviz-research/utils/research_utils.py

pd.options.display.max_colwidth = None
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("max_seq_items", None)
pd.set_option("display.width", None)
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys

sys.path.insert(1, "/Users/jazz/Recidiviz/pulse-data")

from recidiviz.calculator.modeling.population_projection.super_simulation.time_converter import (
    TimeConverter,
)
from recidiviz.calculator.modeling.population_projection.utils.spark_bq_utils import (
    upload_spark_model_inputs,
)
from recidiviz.calculator.modeling.population_projection.utils.spark_preprocessing_utils import (
    convert_dates,
)
from recidiviz.utils.yaml_dict import YAMLDict

logger = logging.getLogger(__name__)
logger.setLevel(level=logging.INFO)

# Get the simulation tag from the model inputs config
yaml_file_path = "tx_gun_minimums_v1.yaml"

simulation_config = YAMLDict.from_path(yaml_file_path)
data_inputs = simulation_config.pop_dict("data_inputs")
simulation_tag = data_inputs.pop("big_query_simulation_tag", str)

# Convert the timestamps to time_steps (relative ints), with 0 being the most recent
# date of data (Sept. 2020)
reference_date = simulation_config.pop("reference_date", float)
time_step = simulation_config.pop("time_step", float)
time_converter = TimeConverter(reference_year=reference_date, time_step=time_step)

# %%
prison_admissions_raw = pd.read_csv(
    "input_data/TX Gun MM Raw Data - prison_admissions.csv"
)

# %%
month_array = pd.DataFrame(
    pd.date_range("2012-09-01", "2022-08-01", freq="MS"), columns=["month"]
)
month_array["fiscal_year"] = month_array.month.dt.to_period("Q-AUG").dt.qyear
prison_admissions = pd.merge(prison_admissions_raw, month_array, how="inner")
prison_admissions = prison_admissions.drop(columns="fiscal_year")

# %%
# fraction of total prison admissions in FY2022 (37428) that were of the affected offense type (4791)
ratio_relevant_offenses = 4791 / prison_admissions.iloc[-1].admissions

affected_prison_admissions_per_year = 1708

# fraction of relevant admissions (4791) that also had a deadly weapon involved (1708)
ratio_deadly_weapon = affected_prison_admissions_per_year / 4791

prison_admissions["deadly_weapon_monthly"] = (
    prison_admissions.admissions * ratio_relevant_offenses * ratio_deadly_weapon / 12
)

# %%
prison_outflows = prison_admissions.rename(
    columns={"deadly_weapon_monthly": "total_population"}
)
prison_outflows.total_population = prison_outflows.total_population.round(1)
prison_outflows.loc[:, "time_step"] = convert_dates(
    time_converter, prison_outflows["month"]
)
prison_outflows = prison_outflows.drop(columns=["admissions", "month"])
prison_outflows
# Out:
#     compartment outflow_to  total_population  time_step
# 0      pretrial     prison             163.3       -124
# 1      pretrial     prison             163.3       -123
# 2      pretrial     prison             163.3       -122
# 3      pretrial     prison             163.3       -121
# 4      pretrial     prison             163.3       -120
# 5      pretrial     prison             163.3       -119
# 6      pretrial     prison             163.3       -118
# 7      pretrial     prison             163.3       -117
# 8      pretrial     prison             163.3       -116
# 9      pretrial     prison             163.3       -115
# 10     pretrial     prison             163.3       -114
# 11     pretrial     prison             163.3       -113
# 12     pretrial     prison             162.5       -112
# 13     pretrial     prison             162.5       -111
# 14     pretrial     prison             162.5       -110
# 15     pretrial     prison             162.5       -109
# 16     pretrial     prison             162.5       -108
# 17     pretrial     prison             162.5       -107
# 18     pretrial     prison             162.5       -106
# 19     pretrial     prison             162.5       -105
# 20     pretrial     prison             162.5       -104
# 21     pretrial     prison             162.5       -103
# 22     pretrial     prison             162.5       -102
# 23     pretrial     prison             162.5       -101
# 24     pretrial     prison             158.9       -100
# 25     pretrial     prison             158.9        -99
# 26     pretrial     prison             158.9        -98
# 27     pretrial     prison             158.9        -97
# 28     pretrial     prison             158.9        -96
# 29     pretrial     prison             158.9        -95
# 30     pretrial     prison             158.9        -94
# 31     pretrial     prison             158.9        -93
# 32     pretrial     prison             158.9        -92
# 33     pretrial     prison             158.9        -91
# 34     pretrial     prison             158.9        -90
# 35     pretrial     prison             158.9        -89
# 36     pretrial     prison             157.4        -88
# 37     pretrial     prison             157.4        -87
# 38     pretrial     prison             157.4        -86
# 39     pretrial     prison             157.4        -85
# 40     pretrial     prison             157.4        -84
# 41     pretrial     prison             157.4        -83
# 42     pretrial     prison             157.4        -82
# 43     pretrial     prison             157.4        -81
# 44     pretrial     prison             157.4        -80
# 45     pretrial     prison             157.4        -79
# 46     pretrial     prison             157.4        -78
# 47     pretrial     prison             157.4        -77
# 48     pretrial     prison             154.4        -76
# 49     pretrial     prison             154.4        -75
# 50     pretrial     prison             154.4        -74
# 51     pretrial     prison             154.4        -73
# 52     pretrial     prison             154.4        -72
# 53     pretrial     prison             154.4        -71
# 54     pretrial     prison             154.4        -70
# 55     pretrial     prison             154.4        -69
# 56     pretrial     prison             154.4        -68
# 57     pretrial     prison             154.4        -67
# 58     pretrial     prison             154.4        -66
# 59     pretrial     prison             154.4        -65
# 60     pretrial     prison             161.4        -64
# 61     pretrial     prison             161.4        -63
# 62     pretrial     prison             161.4        -62
# 63     pretrial     prison             161.4        -61
# 64     pretrial     prison             161.4        -60
# 65     pretrial     prison             161.4        -59
# 66     pretrial     prison             161.4        -58
# 67     pretrial     prison             161.4        -57
# 68     pretrial     prison             161.4        -56
# 69     pretrial     prison             161.4        -55
# 70     pretrial     prison             161.4        -54
# 71     pretrial     prison             161.4        -53
# 72     pretrial     prison             156.2        -52
# 73     pretrial     prison             156.2        -51
# 74     pretrial     prison             156.2        -50
# 75     pretrial     prison             156.2        -49
# 76     pretrial     prison             156.2        -48
# 77     pretrial     prison             156.2        -47
# 78     pretrial     prison             156.2        -46
# 79     pretrial     prison             156.2        -45
# 80     pretrial     prison             156.2        -44
# 81     pretrial     prison             156.2        -43
# 82     pretrial     prison             156.2        -42
# 83     pretrial     prison             156.2        -41
# 84     pretrial     prison              94.5        -40
# 85     pretrial     prison              94.5        -39
# 86     pretrial     prison              94.5        -38
# 87     pretrial     prison              94.5        -37
# 88     pretrial     prison              94.5        -36
# 89     pretrial     prison              94.5        -35
# 90     pretrial     prison              94.5        -34
# 91     pretrial     prison              94.5        -33
# 92     pretrial     prison              94.5        -32
# 93     pretrial     prison              94.5        -31
# 94     pretrial     prison              94.5        -30
# 95     pretrial     prison              94.5        -29
# 96     pretrial     prison             120.1        -28
# 97     pretrial     prison             120.1        -27
# 98     pretrial     prison             120.1        -26
# 99     pretrial     prison             120.1        -25
# 100    pretrial     prison             120.1        -24
# 101    pretrial     prison             120.1        -23
# 102    pretrial     prison             120.1        -22
# 103    pretrial     prison             120.1        -21
# 104    pretrial     prison             120.1        -20
# 105    pretrial     prison             120.1        -19
# 106    pretrial     prison             120.1        -18
# 107    pretrial     prison             120.1        -17
# 108    pretrial     prison             142.3        -16
# 109    pretrial     prison             142.3        -15
# 110    pretrial     prison             142.3        -14
# 111    pretrial     prison             142.3        -13
# 112    pretrial     prison             142.3        -12
# 113    pretrial     prison             142.3        -11
# 114    pretrial     prison             142.3        -10
# 115    pretrial     prison             142.3         -9
# 116    pretrial     prison             142.3         -8
# 117    pretrial     prison             142.3         -7
# 118    pretrial     prison             142.3         -6
# 119    pretrial     prison             142.3         -5

# %%
probation_adm = float(round(1982 / 12 * ratio_deadly_weapon))
probation_adm
# Out:
# 59.0

# %%
probation_outflows = pd.DataFrame(prison_outflows.time_step, columns=["time_step"])
probation_outflows["compartment"] = "pretrial"
probation_outflows["outflow_to"] = "probation"
probation_outflows["total_population"] = probation_adm
probation_outflows
# Out:
#      time_step compartment outflow_to  total_population
# 0         -124    pretrial  probation              59.0
# 1         -123    pretrial  probation              59.0
# 2         -122    pretrial  probation              59.0
# 3         -121    pretrial  probation              59.0
# 4         -120    pretrial  probation              59.0
# 5         -119    pretrial  probation              59.0
# 6         -118    pretrial  probation              59.0
# 7         -117    pretrial  probation              59.0
# 8         -116    pretrial  probation              59.0
# 9         -115    pretrial  probation              59.0
# 10        -114    pretrial  probation              59.0
# 11        -113    pretrial  probation              59.0
# 12        -112    pretrial  probation              59.0
# 13        -111    pretrial  probation              59.0
# 14        -110    pretrial  probation              59.0
# 15        -109    pretrial  probation              59.0
# 16        -108    pretrial  probation              59.0
# 17        -107    pretrial  probation              59.0
# 18        -106    pretrial  probation              59.0
# 19        -105    pretrial  probation              59.0
# 20        -104    pretrial  probation              59.0
# 21        -103    pretrial  probation              59.0
# 22        -102    pretrial  probation              59.0
# 23        -101    pretrial  probation              59.0
# 24        -100    pretrial  probation              59.0
# 25         -99    pretrial  probation              59.0
# 26         -98    pretrial  probation              59.0
# 27         -97    pretrial  probation              59.0
# 28         -96    pretrial  probation              59.0
# 29         -95    pretrial  probation              59.0
# 30         -94    pretrial  probation              59.0
# 31         -93    pretrial  probation              59.0
# 32         -92    pretrial  probation              59.0
# 33         -91    pretrial  probation              59.0
# 34         -90    pretrial  probation              59.0
# 35         -89    pretrial  probation              59.0
# 36         -88    pretrial  probation              59.0
# 37         -87    pretrial  probation              59.0
# 38         -86    pretrial  probation              59.0
# 39         -85    pretrial  probation              59.0
# 40         -84    pretrial  probation              59.0
# 41         -83    pretrial  probation              59.0
# 42         -82    pretrial  probation              59.0
# 43         -81    pretrial  probation              59.0
# 44         -80    pretrial  probation              59.0
# 45         -79    pretrial  probation              59.0
# 46         -78    pretrial  probation              59.0
# 47         -77    pretrial  probation              59.0
# 48         -76    pretrial  probation              59.0
# 49         -75    pretrial  probation              59.0
# 50         -74    pretrial  probation              59.0
# 51         -73    pretrial  probation              59.0
# 52         -72    pretrial  probation              59.0
# 53         -71    pretrial  probation              59.0
# 54         -70    pretrial  probation              59.0
# 55         -69    pretrial  probation              59.0
# 56         -68    pretrial  probation              59.0
# 57         -67    pretrial  probation              59.0
# 58         -66    pretrial  probation              59.0
# 59         -65    pretrial  probation              59.0
# 60         -64    pretrial  probation              59.0
# 61         -63    pretrial  probation              59.0
# 62         -62    pretrial  probation              59.0
# 63         -61    pretrial  probation              59.0
# 64         -60    pretrial  probation              59.0
# 65         -59    pretrial  probation              59.0
# 66         -58    pretrial  probation              59.0
# 67         -57    pretrial  probation              59.0
# 68         -56    pretrial  probation              59.0
# 69         -55    pretrial  probation              59.0
# 70         -54    pretrial  probation              59.0
# 71         -53    pretrial  probation              59.0
# 72         -52    pretrial  probation              59.0
# 73         -51    pretrial  probation              59.0
# 74         -50    pretrial  probation              59.0
# 75         -49    pretrial  probation              59.0
# 76         -48    pretrial  probation              59.0
# 77         -47    pretrial  probation              59.0
# 78         -46    pretrial  probation              59.0
# 79         -45    pretrial  probation              59.0
# 80         -44    pretrial  probation              59.0
# 81         -43    pretrial  probation              59.0
# 82         -42    pretrial  probation              59.0
# 83         -41    pretrial  probation              59.0
# 84         -40    pretrial  probation              59.0
# 85         -39    pretrial  probation              59.0
# 86         -38    pretrial  probation              59.0
# 87         -37    pretrial  probation              59.0
# 88         -36    pretrial  probation              59.0
# 89         -35    pretrial  probation              59.0
# 90         -34    pretrial  probation              59.0
# 91         -33    pretrial  probation              59.0
# 92         -32    pretrial  probation              59.0
# 93         -31    pretrial  probation              59.0
# 94         -30    pretrial  probation              59.0
# 95         -29    pretrial  probation              59.0
# 96         -28    pretrial  probation              59.0
# 97         -27    pretrial  probation              59.0
# 98         -26    pretrial  probation              59.0
# 99         -25    pretrial  probation              59.0
# 100        -24    pretrial  probation              59.0
# 101        -23    pretrial  probation              59.0
# 102        -22    pretrial  probation              59.0
# 103        -21    pretrial  probation              59.0
# 104        -20    pretrial  probation              59.0
# 105        -19    pretrial  probation              59.0
# 106        -18    pretrial  probation              59.0
# 107        -17    pretrial  probation              59.0
# 108        -16    pretrial  probation              59.0
# 109        -15    pretrial  probation              59.0
# 110        -14    pretrial  probation              59.0
# 111        -13    pretrial  probation              59.0
# 112        -12    pretrial  probation              59.0
# 113        -11    pretrial  probation              59.0
# 114        -10    pretrial  probation              59.0
# 115         -9    pretrial  probation              59.0
# 116         -8    pretrial  probation              59.0
# 117         -7    pretrial  probation              59.0
# 118         -6    pretrial  probation              59.0
# 119         -5    pretrial  probation              59.0

# %%
outflows = pd.concat([prison_outflows, probation_outflows])
outflows["crime_type"] = "gun"
outflows
# Out:
#     compartment outflow_to  total_population  time_step crime_type
# 0      pretrial     prison             163.3       -124        gun
# 1      pretrial     prison             163.3       -123        gun
# 2      pretrial     prison             163.3       -122        gun
# 3      pretrial     prison             163.3       -121        gun
# 4      pretrial     prison             163.3       -120        gun
# 5      pretrial     prison             163.3       -119        gun
# 6      pretrial     prison             163.3       -118        gun
# 7      pretrial     prison             163.3       -117        gun
# 8      pretrial     prison             163.3       -116        gun
# 9      pretrial     prison             163.3       -115        gun
# 10     pretrial     prison             163.3       -114        gun
# 11     pretrial     prison             163.3       -113        gun
# 12     pretrial     prison             162.5       -112        gun
# 13     pretrial     prison             162.5       -111        gun
# 14     pretrial     prison             162.5       -110        gun
# 15     pretrial     prison             162.5       -109        gun
# 16     pretrial     prison             162.5       -108        gun
# 17     pretrial     prison             162.5       -107        gun
# 18     pretrial     prison             162.5       -106        gun
# 19     pretrial     prison             162.5       -105        gun
# 20     pretrial     prison             162.5       -104        gun
# 21     pretrial     prison             162.5       -103        gun
# 22     pretrial     prison             162.5       -102        gun
# 23     pretrial     prison             162.5       -101        gun
# 24     pretrial     prison             158.9       -100        gun
# 25     pretrial     prison             158.9        -99        gun
# 26     pretrial     prison             158.9        -98        gun
# 27     pretrial     prison             158.9        -97        gun
# 28     pretrial     prison             158.9        -96        gun
# 29     pretrial     prison             158.9        -95        gun
# 30     pretrial     prison             158.9        -94        gun
# 31     pretrial     prison             158.9        -93        gun
# 32     pretrial     prison             158.9        -92        gun
# 33     pretrial     prison             158.9        -91        gun
# 34     pretrial     prison             158.9        -90        gun
# 35     pretrial     prison             158.9        -89        gun
# 36     pretrial     prison             157.4        -88        gun
# 37     pretrial     prison             157.4        -87        gun
# 38     pretrial     prison             157.4        -86        gun
# 39     pretrial     prison             157.4        -85        gun
# 40     pretrial     prison             157.4        -84        gun
# 41     pretrial     prison             157.4        -83        gun
# 42     pretrial     prison             157.4        -82        gun
# 43     pretrial     prison             157.4        -81        gun
# 44     pretrial     prison             157.4        -80        gun
# 45     pretrial     prison             157.4        -79        gun
# 46     pretrial     prison             157.4        -78        gun
# 47     pretrial     prison             157.4        -77        gun
# 48     pretrial     prison             154.4        -76        gun
# 49     pretrial     prison             154.4        -75        gun
# 50     pretrial     prison             154.4        -74        gun
# 51     pretrial     prison             154.4        -73        gun
# 52     pretrial     prison             154.4        -72        gun
# 53     pretrial     prison             154.4        -71        gun
# 54     pretrial     prison             154.4        -70        gun
# 55     pretrial     prison             154.4        -69        gun
# 56     pretrial     prison             154.4        -68        gun
# 57     pretrial     prison             154.4        -67        gun
# 58     pretrial     prison             154.4        -66        gun
# 59     pretrial     prison             154.4        -65        gun
# 60     pretrial     prison             161.4        -64        gun
# 61     pretrial     prison             161.4        -63        gun
# 62     pretrial     prison             161.4        -62        gun
# 63     pretrial     prison             161.4        -61        gun
# 64     pretrial     prison             161.4        -60        gun
# 65     pretrial     prison             161.4        -59        gun
# 66     pretrial     prison             161.4        -58        gun
# 67     pretrial     prison             161.4        -57        gun
# 68     pretrial     prison             161.4        -56        gun
# 69     pretrial     prison             161.4        -55        gun
# 70     pretrial     prison             161.4        -54        gun
# 71     pretrial     prison             161.4        -53        gun
# 72     pretrial     prison             156.2        -52        gun
# 73     pretrial     prison             156.2        -51        gun
# 74     pretrial     prison             156.2        -50        gun
# 75     pretrial     prison             156.2        -49        gun
# 76     pretrial     prison             156.2        -48        gun
# 77     pretrial     prison             156.2        -47        gun
# 78     pretrial     prison             156.2        -46        gun
# 79     pretrial     prison             156.2        -45        gun
# 80     pretrial     prison             156.2        -44        gun
# 81     pretrial     prison             156.2        -43        gun
# 82     pretrial     prison             156.2        -42        gun
# 83     pretrial     prison             156.2        -41        gun
# 84     pretrial     prison              94.5        -40        gun
# 85     pretrial     prison              94.5        -39        gun
# 86     pretrial     prison              94.5        -38        gun
# 87     pretrial     prison              94.5        -37        gun
# 88     pretrial     prison              94.5        -36        gun
# 89     pretrial     prison              94.5        -35        gun
# 90     pretrial     prison              94.5        -34        gun
# 91     pretrial     prison              94.5        -33        gun
# 92     pretrial     prison              94.5        -32        gun
# 93     pretrial     prison              94.5        -31        gun
# 94     pretrial     prison              94.5        -30        gun
# 95     pretrial     prison              94.5        -29        gun
# 96     pretrial     prison             120.1        -28        gun
# 97     pretrial     prison             120.1        -27        gun
# 98     pretrial     prison             120.1        -26        gun
# 99     pretrial     prison             120.1        -25        gun
# 100    pretrial     prison             120.1        -24        gun
# 101    pretrial     prison             120.1        -23        gun
# 102    pretrial     prison             120.1        -22        gun
# 103    pretrial     prison             120.1        -21        gun
# 104    pretrial     prison             120.1        -20        gun
# 105    pretrial     prison             120.1        -19        gun
# 106    pretrial     prison             120.1        -18        gun
# 107    pretrial     prison             120.1        -17        gun
# 108    pretrial     prison             142.3        -16        gun
# 109    pretrial     prison             142.3        -15        gun
# 110    pretrial     prison             142.3        -14        gun
# 111    pretrial     prison             142.3        -13        gun
# 112    pretrial     prison             142.3        -12        gun
# 113    pretrial     prison             142.3        -11        gun
# 114    pretrial     prison             142.3        -10        gun
# 115    pretrial     prison             142.3         -9        gun
# 116    pretrial     prison             142.3         -8        gun
# 117    pretrial     prison             142.3         -7        gun
# 118    pretrial     prison             142.3         -6        gun
# 119    pretrial     prison             142.3         -5        gun
# 0      pretrial  probation              59.0       -124        gun
# 1      pretrial  probation              59.0       -123        gun
# 2      pretrial  probation              59.0       -122        gun
# 3      pretrial  probation              59.0       -121        gun
# 4      pretrial  probation              59.0       -120        gun
# 5      pretrial  probation              59.0       -119        gun
# 6      pretrial  probation              59.0       -118        gun
# 7      pretrial  probation              59.0       -117        gun
# 8      pretrial  probation              59.0       -116        gun
# 9      pretrial  probation              59.0       -115        gun
# 10     pretrial  probation              59.0       -114        gun
# 11     pretrial  probation              59.0       -113        gun
# 12     pretrial  probation              59.0       -112        gun
# 13     pretrial  probation              59.0       -111        gun
# 14     pretrial  probation              59.0       -110        gun
# 15     pretrial  probation              59.0       -109        gun
# 16     pretrial  probation              59.0       -108        gun
# 17     pretrial  probation              59.0       -107        gun
# 18     pretrial  probation              59.0       -106        gun
# 19     pretrial  probation              59.0       -105        gun
# 20     pretrial  probation              59.0       -104        gun
# 21     pretrial  probation              59.0       -103        gun
# 22     pretrial  probation              59.0       -102        gun
# 23     pretrial  probation              59.0       -101        gun
# 24     pretrial  probation              59.0       -100        gun
# 25     pretrial  probation              59.0        -99        gun
# 26     pretrial  probation              59.0        -98        gun
# 27     pretrial  probation              59.0        -97        gun
# 28     pretrial  probation              59.0        -96        gun
# 29     pretrial  probation              59.0        -95        gun
# 30     pretrial  probation              59.0        -94        gun
# 31     pretrial  probation              59.0        -93        gun
# 32     pretrial  probation              59.0        -92        gun
# 33     pretrial  probation              59.0        -91        gun
# 34     pretrial  probation              59.0        -90        gun
# 35     pretrial  probation              59.0        -89        gun
# 36     pretrial  probation              59.0        -88        gun
# 37     pretrial  probation              59.0        -87        gun
# 38     pretrial  probation              59.0        -86        gun
# 39     pretrial  probation              59.0        -85        gun
# 40     pretrial  probation              59.0        -84        gun
# 41     pretrial  probation              59.0        -83        gun
# 42     pretrial  probation              59.0        -82        gun
# 43     pretrial  probation              59.0        -81        gun
# 44     pretrial  probation              59.0        -80        gun
# 45     pretrial  probation              59.0        -79        gun
# 46     pretrial  probation              59.0        -78        gun
# 47     pretrial  probation              59.0        -77        gun
# 48     pretrial  probation              59.0        -76        gun
# 49     pretrial  probation              59.0        -75        gun
# 50     pretrial  probation              59.0        -74        gun
# 51     pretrial  probation              59.0        -73        gun
# 52     pretrial  probation              59.0        -72        gun
# 53     pretrial  probation              59.0        -71        gun
# 54     pretrial  probation              59.0        -70        gun
# 55     pretrial  probation              59.0        -69        gun
# 56     pretrial  probation              59.0        -68        gun
# 57     pretrial  probation              59.0        -67        gun
# 58     pretrial  probation              59.0        -66        gun
# 59     pretrial  probation              59.0        -65        gun
# 60     pretrial  probation              59.0        -64        gun
# 61     pretrial  probation              59.0        -63        gun
# 62     pretrial  probation              59.0        -62        gun
# 63     pretrial  probation              59.0        -61        gun
# 64     pretrial  probation              59.0        -60        gun
# 65     pretrial  probation              59.0        -59        gun
# 66     pretrial  probation              59.0        -58        gun
# 67     pretrial  probation              59.0        -57        gun
# 68     pretrial  probation              59.0        -56        gun
# 69     pretrial  probation              59.0        -55        gun
# 70     pretrial  probation              59.0        -54        gun
# 71     pretrial  probation              59.0        -53        gun
# 72     pretrial  probation              59.0        -52        gun
# 73     pretrial  probation              59.0        -51        gun
# 74     pretrial  probation              59.0        -50        gun
# 75     pretrial  probation              59.0        -49        gun
# 76     pretrial  probation              59.0        -48        gun
# 77     pretrial  probation              59.0        -47        gun
# 78     pretrial  probation              59.0        -46        gun
# 79     pretrial  probation              59.0        -45        gun
# 80     pretrial  probation              59.0        -44        gun
# 81     pretrial  probation              59.0        -43        gun
# 82     pretrial  probation              59.0        -42        gun
# 83     pretrial  probation              59.0        -41        gun
# 84     pretrial  probation              59.0        -40        gun
# 85     pretrial  probation              59.0        -39        gun
# 86     pretrial  probation              59.0        -38        gun
# 87     pretrial  probation              59.0        -37        gun
# 88     pretrial  probation              59.0        -36        gun
# 89     pretrial  probation              59.0        -35        gun
# 90     pretrial  probation              59.0        -34        gun
# 91     pretrial  probation              59.0        -33        gun
# 92     pretrial  probation              59.0        -32        gun
# 93     pretrial  probation              59.0        -31        gun
# 94     pretrial  probation              59.0        -30        gun
# 95     pretrial  probation              59.0        -29        gun
# 96     pretrial  probation              59.0        -28        gun
# 97     pretrial  probation              59.0        -27        gun
# 98     pretrial  probation              59.0        -26        gun
# 99     pretrial  probation              59.0        -25        gun
# 100    pretrial  probation              59.0        -24        gun
# 101    pretrial  probation              59.0        -23        gun
# 102    pretrial  probation              59.0        -22        gun
# 103    pretrial  probation              59.0        -21        gun
# 104    pretrial  probation              59.0        -20        gun
# 105    pretrial  probation              59.0        -19        gun
# 106    pretrial  probation              59.0        -18        gun
# 107    pretrial  probation              59.0        -17        gun
# 108    pretrial  probation              59.0        -16        gun
# 109    pretrial  probation              59.0        -15        gun
# 110    pretrial  probation              59.0        -14        gun
# 111    pretrial  probation              59.0        -13        gun
# 112    pretrial  probation              59.0        -12        gun
# 113    pretrial  probation              59.0        -11        gun
# 114    pretrial  probation              59.0        -10        gun
# 115    pretrial  probation              59.0         -9        gun
# 116    pretrial  probation              59.0         -8        gun
# 117    pretrial  probation              59.0         -7        gun
# 118    pretrial  probation              59.0         -6        gun
# 119    pretrial  probation              59.0         -5        gun

# %% [markdown]
# # transitions

# %%
# pull baseline sentence length distribution for everyone in TX prisons
input_trans = pd.read_csv(
    "input_data/TX Gun MM Raw Data - transitions_prison.csv", thousands=","
)
input_trans
# Out:
#               bin  sen_count  years
# 0         2 Years     8363.0      1
# 1    3 to 5 Years    14735.0      4
# 2   6 to 10 Years     8251.0      8
# 3  11 to 20 Years     3550.0     15
# 4  21 to 30 Years     1137.0     25
# 5  31 to 40 Years      526.0     35
# 6  41 to 59 Years      327.0     50
# 7             60+      539.0     80

# %%
7.8 / 7.3
# Out:
# 1.0684931506849316

# %%
avg_sen_lengths_by_crime_type = (
    pd.read_csv("input_data/TX Gun MM Raw Data - avg_sen_length_by_type.csv")
    .rename(columns={"Unnamed: 0": "crime_type"})
    .loc[:3]
)
# find arbitrary scale factor to multiply the sentence distribution
#     for each crime type by a scalar to stretch/compress
#     distribution to match average sentence length
total_avg_sentence_length = 7.3
calibration_factor = 1.0684931506849316
calibrated_total_avg_sentence_length = total_avg_sentence_length * calibration_factor
avg_sen_lengths_by_crime_type["multiplier"] = (
    avg_sen_lengths_by_crime_type.avg_sentence_length
    / calibrated_total_avg_sentence_length
)
avg_sen_lengths_by_crime_type.sort_values(by="avg_sentence_length")
# Out:
#   crime_type  avg_sentence_length  multiplier
# 3      Other                  4.9    0.628205
# 1   Property                  5.4    0.692308
# 2       Drug                  5.7    0.730769
# 0    Violent                 10.2    1.307692

# %%
# Do the multiply step with that scale factor
trans = pd.merge(input_trans, avg_sen_lengths_by_crime_type, how="cross")
trans["years_adj"] = trans.years * trans.multiplier

# %%
# check that avg sens match the reported numbers above
trans.groupby("crime_type").apply(
    lambda x: np.average(x.years_adj, weights=x.sen_count)
).sort_values()
# Out:
# crime_type
# Other        4.915569
# Property     5.417158
# Drug         5.718111
# Violent     10.232409
# dtype: float64

# %%
trans["sen_months"] = trans.years_adj * 12
trans.sort_values(by=["crime_type", "years"])
# Out:
#                bin  sen_count  years crime_type  avg_sentence_length  \
# 2          2 Years     8363.0      1       Drug                  5.7
# 6     3 to 5 Years    14735.0      4       Drug                  5.7
# 10   6 to 10 Years     8251.0      8       Drug                  5.7
# 14  11 to 20 Years     3550.0     15       Drug                  5.7
# 18  21 to 30 Years     1137.0     25       Drug                  5.7
# 22  31 to 40 Years      526.0     35       Drug                  5.7
# 26  41 to 59 Years      327.0     50       Drug                  5.7
# 30             60+      539.0     80       Drug                  5.7
# 3          2 Years     8363.0      1      Other                  4.9
# 7     3 to 5 Years    14735.0      4      Other                  4.9
# 11   6 to 10 Years     8251.0      8      Other                  4.9
# 15  11 to 20 Years     3550.0     15      Other                  4.9
# 19  21 to 30 Years     1137.0     25      Other                  4.9
# 23  31 to 40 Years      526.0     35      Other                  4.9
# 27  41 to 59 Years      327.0     50      Other                  4.9
# 31             60+      539.0     80      Other                  4.9
# 1          2 Years     8363.0      1   Property                  5.4
# 5     3 to 5 Years    14735.0      4   Property                  5.4
# 9    6 to 10 Years     8251.0      8   Property                  5.4
# 13  11 to 20 Years     3550.0     15   Property                  5.4
# 17  21 to 30 Years     1137.0     25   Property                  5.4
# 21  31 to 40 Years      526.0     35   Property                  5.4
# 25  41 to 59 Years      327.0     50   Property                  5.4
# 29             60+      539.0     80   Property                  5.4
# 0          2 Years     8363.0      1    Violent                 10.2
# 4     3 to 5 Years    14735.0      4    Violent                 10.2
# 8    6 to 10 Years     8251.0      8    Violent                 10.2
# 12  11 to 20 Years     3550.0     15    Violent                 10.2
# 16  21 to 30 Years     1137.0     25    Violent                 10.2
# 20  31 to 40 Years      526.0     35    Violent                 10.2
# 24  41 to 59 Years      327.0     50    Violent                 10.2
# 28             60+      539.0     80    Violent                 10.2
#
#     multiplier   years_adj   sen_months
# 2     0.730769    0.730769     8.769231
# 6     0.730769    2.923077    35.076923
# 10    0.730769    5.846154    70.153846
# 14    0.730769   10.961538   131.538462
# 18    0.730769   18.269231   219.230769
# 22    0.730769   25.576923   306.923077
# 26    0.730769   36.538462   438.461538
# 30    0.730769   58.461538   701.538462
# 3     0.628205    0.628205     7.538462
# 7     0.628205    2.512821    30.153846
# 11    0.628205    5.025641    60.307692
# 15    0.628205    9.423077   113.076923
# 19    0.628205   15.705128   188.461538
# 23    0.628205   21.987179   263.846154
# 27    0.628205   31.410256   376.923077
# 31    0.628205   50.256410   603.076923
# 1     0.692308    0.692308     8.307692
# 5     0.692308    2.769231    33.230769
# 9     0.692308    5.538462    66.461538
# 13    0.692308   10.384615   124.615385
# 17    0.692308   17.307692   207.692308
# 21    0.692308   24.230769   290.769231
# 25    0.692308   34.615385   415.384615
# 29    0.692308   55.384615   664.615385
# 0     1.307692    1.307692    15.692308
# 4     1.307692    5.230769    62.769231
# 8     1.307692   10.461538   125.538462
# 12    1.307692   19.615385   235.384615
# 16    1.307692   32.692308   392.307692
# 20    1.307692   45.769231   549.230769
# 24    1.307692   65.384615   784.615385
# 28    1.307692  104.615385  1255.384615

# %%
trans_sens = trans.drop(
    columns=["bin", "years", "multiplier", "avg_sentence_length", "years_adj"]
).sort_values(by=["crime_type", "sen_months"])

# %%
# pull discharge data (% to parole, % to liberty, etc.)
discharges = pd.read_csv("input_data/TX Gun MM Raw Data - discharge_type.csv")
discharges["percent_of_releases"] = discharges.releases / discharges.releases.sum()
discharges = discharges.drop(columns="releases").sort_values(
    by="percent_of_releases", ascending=False
)
discharges
# Out:
#                 Category  percent_of_releases
# 2                 Parole             0.518773
# 3                    DMS             0.327416
# 0              Discharge             0.145362
# 4                     MS             0.004361
# 1  Community Supervision             0.004087

# %%
trans_wth_discharge_type = pd.merge(trans_sens, discharges, how="cross")
trans_wth_discharge_type
# Out:
#      sen_count crime_type   sen_months               Category  \
# 0       8363.0       Drug     8.769231                 Parole
# 1       8363.0       Drug     8.769231                    DMS
# 2       8363.0       Drug     8.769231              Discharge
# 3       8363.0       Drug     8.769231                     MS
# 4       8363.0       Drug     8.769231  Community Supervision
# 5      14735.0       Drug    35.076923                 Parole
# 6      14735.0       Drug    35.076923                    DMS
# 7      14735.0       Drug    35.076923              Discharge
# 8      14735.0       Drug    35.076923                     MS
# 9      14735.0       Drug    35.076923  Community Supervision
# 10      8251.0       Drug    70.153846                 Parole
# 11      8251.0       Drug    70.153846                    DMS
# 12      8251.0       Drug    70.153846              Discharge
# 13      8251.0       Drug    70.153846                     MS
# 14      8251.0       Drug    70.153846  Community Supervision
# 15      3550.0       Drug   131.538462                 Parole
# 16      3550.0       Drug   131.538462                    DMS
# 17      3550.0       Drug   131.538462              Discharge
# 18      3550.0       Drug   131.538462                     MS
# 19      3550.0       Drug   131.538462  Community Supervision
# 20      1137.0       Drug   219.230769                 Parole
# 21      1137.0       Drug   219.230769                    DMS
# 22      1137.0       Drug   219.230769              Discharge
# 23      1137.0       Drug   219.230769                     MS
# 24      1137.0       Drug   219.230769  Community Supervision
# 25       526.0       Drug   306.923077                 Parole
# 26       526.0       Drug   306.923077                    DMS
# 27       526.0       Drug   306.923077              Discharge
# 28       526.0       Drug   306.923077                     MS
# 29       526.0       Drug   306.923077  Community Supervision
# 30       327.0       Drug   438.461538                 Parole
# 31       327.0       Drug   438.461538                    DMS
# 32       327.0       Drug   438.461538              Discharge
# 33       327.0       Drug   438.461538                     MS
# 34       327.0       Drug   438.461538  Community Supervision
# 35       539.0       Drug   701.538462                 Parole
# 36       539.0       Drug   701.538462                    DMS
# 37       539.0       Drug   701.538462              Discharge
# 38       539.0       Drug   701.538462                     MS
# 39       539.0       Drug   701.538462  Community Supervision
# 40      8363.0      Other     7.538462                 Parole
# 41      8363.0      Other     7.538462                    DMS
# 42      8363.0      Other     7.538462              Discharge
# 43      8363.0      Other     7.538462                     MS
# 44      8363.0      Other     7.538462  Community Supervision
# 45     14735.0      Other    30.153846                 Parole
# 46     14735.0      Other    30.153846                    DMS
# 47     14735.0      Other    30.153846              Discharge
# 48     14735.0      Other    30.153846                     MS
# 49     14735.0      Other    30.153846  Community Supervision
# 50      8251.0      Other    60.307692                 Parole
# 51      8251.0      Other    60.307692                    DMS
# 80              0.518773
# 81              0.327416
# 82              0.145362
# 83              0.004361
# 84              0.004087
# 85              0.518773
# 86              0.327416
# 87              0.145362
# 88              0.004361
# 89              0.004087
# 90              0.518773
# 91              0.327416
# 92              0.145362
# 93              0.004361
# 94              0.004087
# 95              0.518773
# 96              0.327416
# 97              0.145362
# 98              0.004361
# 99              0.004087
# 100             0.518773
# 101             0.327416
# 102             0.145362
# 103             0.004361
# 104             0.004087
# 105             0.518773
# 106             0.327416
# 107             0.145362
# 108             0.004361
# 109             0.004087
# 110             0.518773
# 111             0.327416
# 112             0.145362
# 113             0.004361
# 114             0.004087
# 115             0.518773
# 116             0.327416
# 117             0.145362
# 118             0.004361
# 119             0.004087
# 120             0.518773
# 121             0.327416
# 122             0.145362
# 123             0.004361
# 124             0.004087
# 125             0.518773
# 126             0.327416
# 127             0.145362
# 128             0.004361
# 129             0.004087
# 130             0.518773
# 131             0.327416
# 132             0.145362
# 133             0.004361
# 134             0.004087
# 135             0.518773
# 136             0.327416
# 137             0.145362
# 138             0.004361
# 139             0.004087
# 140             0.518773
# 141             0.327416
# 142             0.145362
# 143             0.004361
# 144             0.004087
# 145             0.518773
# 146             0.327416
# 147             0.145362
# 148             0.004361
# 149             0.004087
# 150             0.518773
# 151             0.327416
# 152             0.145362
# 153             0.004361
# 154             0.004087
# 155             0.518773
# 156             0.327416
# 157             0.145362
# 158             0.004361
# 159             0.004087

# %%
# read los data, by crime category and discharge type
los_by_sen_type = (
    pd.read_csv("input_data/TX Gun MM Raw Data - los_per_crime_type.csv")
    .loc[:4]  # ignore "Total" last row
    .melt(
        id_vars=["Category"],
        value_vars=["Violent", "Property", "Drug", "Other"],
        var_name="crime_type",
        value_name="los_percent_of_sen",
    )
)
los_by_sen_type
# Out:
#                  Category crime_type  los_percent_of_sen
# 0   Community Supervision    Violent               0.104
# 1                  Parole    Violent               0.682
# 2                     DMS    Violent               0.637
# 3                      MS    Violent               0.722
# 4               Discharge    Violent               1.000
# 5   Community Supervision   Property               0.141
# 6                  Parole   Property               0.474
# 7                     DMS   Property               0.615
# 8                      MS   Property               0.838
# 9               Discharge   Property               1.000
# 10  Community Supervision       Drug               0.101
# 11                 Parole       Drug               0.410
# 12                    DMS       Drug               0.587
# 13                     MS       Drug               0.862
# 14              Discharge       Drug               1.000
# 15  Community Supervision      Other               0.112
# 16                 Parole      Other               0.449
# 17                    DMS      Other               0.593
# 18                     MS      Other               0.682
# 19              Discharge      Other               1.000

# %%
trans_with_los_by_discharge = pd.merge(
    trans_wth_discharge_type, los_by_sen_type, how="inner"
)

# %%
trans_with_los_by_discharge["total_population"] = (
    trans_with_los_by_discharge.sen_count
    * trans_with_los_by_discharge.percent_of_releases
)
trans_with_los_by_discharge["prison_los"] = (
    trans_with_los_by_discharge.sen_months
    * trans_with_los_by_discharge.los_percent_of_sen
)
trans_with_los_by_discharge["parole_los"] = (
    trans_with_los_by_discharge.sen_months - trans_with_los_by_discharge.prison_los
)

# %%
# exclude Drug crime type
trans_affected = trans_with_los_by_discharge[
    trans_with_los_by_discharge.crime_type != "Drug"
].copy()

# arbitrary scalar to match affected population LOS from impact report (8.7 yrs)
affected_firearm_scalar = 8.7 / 4.447
trans_affected.prison_los = (
    affected_firearm_scalar * trans_with_los_by_discharge.prison_los
)
trans_affected.prison_los = round(trans_affected.prison_los).astype(float)

trans_affected.parole_los = (
    affected_firearm_scalar * trans_with_los_by_discharge.parole_los
)
trans_affected.parole_los = round(trans_affected.parole_los).astype(float)

trans_affected
# Out:
#      sen_count crime_type   sen_months               Category  \
# 40      8363.0      Other     7.538462                 Parole
# 41     14735.0      Other    30.153846                 Parole
# 42      8251.0      Other    60.307692                 Parole
# 43      3550.0      Other   113.076923                 Parole
# 44      1137.0      Other   188.461538                 Parole
# 45       526.0      Other   263.846154                 Parole
# 46       327.0      Other   376.923077                 Parole
# 47       539.0      Other   603.076923                 Parole
# 48      8363.0      Other     7.538462                    DMS
# 49     14735.0      Other    30.153846                    DMS
# 50      8251.0      Other    60.307692                    DMS
# 51      3550.0      Other   113.076923                    DMS
# 52      1137.0      Other   188.461538                    DMS
# 53       526.0      Other   263.846154                    DMS
# 54       327.0      Other   376.923077                    DMS
# 55       539.0      Other   603.076923                    DMS
# 56      8363.0      Other     7.538462              Discharge
# 57     14735.0      Other    30.153846              Discharge
# 58      8251.0      Other    60.307692              Discharge
# 59      3550.0      Other   113.076923              Discharge
# 60      1137.0      Other   188.461538              Discharge
# 61       526.0      Other   263.846154              Discharge
# 62       327.0      Other   376.923077              Discharge
# 63       539.0      Other   603.076923              Discharge
# 64      8363.0      Other     7.538462                     MS
# 65     14735.0      Other    30.153846                     MS
# 66      8251.0      Other    60.307692                     MS
# 67      3550.0      Other   113.076923                     MS
# 68      1137.0      Other   188.461538                     MS
# 69       526.0      Other   263.846154                     MS
# 70       327.0      Other   376.923077                     MS
# 71       539.0      Other   603.076923                     MS
# 72      8363.0      Other     7.538462  Community Supervision
# 73     14735.0      Other    30.153846  Community Supervision
# 74      8251.0      Other    60.307692  Community Supervision
# 75      3550.0      Other   113.076923  Community Supervision
# 76      1137.0      Other   188.461538  Community Supervision
# 77       526.0      Other   263.846154  Community Supervision
# 78       327.0      Other   376.923077  Community Supervision
# 79       539.0      Other   603.076923  Community Supervision
# 80      8363.0   Property     8.307692                 Parole
# 81     14735.0   Property    33.230769                 Parole
# 82      8251.0   Property    66.461538                 Parole
# 83      3550.0   Property   124.615385                 Parole
# 84      1137.0   Property   207.692308                 Parole
# 85       526.0   Property   290.769231                 Parole
# 86       327.0   Property   415.384615                 Parole
# 87       539.0   Property   664.615385                 Parole
# 88      8363.0   Property     8.307692                    DMS
# 89     14735.0   Property    33.230769                    DMS
# 90      8251.0   Property    66.461538                    DMS
# 91      3550.0   Property   124.615385                    DMS
# 92      1137.0   Property   207.692308                    DMS
# 93       526.0   Property   290.769231                    DMS
# 94       327.0   Property   415.384615                    DMS
# 95       539.0   Property   664.615385                    DMS
# 96      8363.0   Property     8.307692              Discharge
# 97     14735.0   Property    33.230769              Discharge
# 98      8251.0   Property    66.461538              Discharge
# 99      3550.0   Property   124.615385              Discharge
# 100     1137.0   Property   207.692308              Discharge
# 118       698.0
# 119      1117.0
# 120        10.0
# 121        39.0
# 122        78.0
# 123       146.0
# 124       244.0
# 125       342.0
# 126       488.0
# 127       781.0
# 128        11.0
# 129        45.0
# 130        89.0
# 131       167.0
# 132       279.0
# 133       390.0
# 134       557.0
# 135       892.0
# 136         0.0
# 137         0.0
# 138         0.0
# 139         0.0
# 140         0.0
# 141         0.0
# 142         0.0
# 143         0.0
# 144         9.0
# 145        34.0
# 146        68.0
# 147       128.0
# 148       213.0
# 149       299.0
# 150       427.0
# 151       683.0
# 152        28.0
# 153       110.0
# 154       220.0
# 155       413.0
# 156       688.0
# 157       963.0
# 158      1375.0
# 159      2201.0

# %%
np.average(trans_affected.prison_los, weights=trans_affected.total_population) / 12
# Out:
# 8.703936879956446

# %%
prison_trans = trans_affected[
    ["crime_type", "prison_los", "total_population", "Category"]
].copy()
prison_trans["compartment"] = "prison"
prison_trans["outflow_to"] = np.where(
    prison_trans.Category == "Discharge", "liberty", "parole"
)
prison_trans = prison_trans.rename(columns={"prison_los": "compartment_duration"})
prison_trans.compartment_duration = prison_trans.compartment_duration.clip(
    upper=40 * 12
)

# %%
prison_transitions = (
    prison_trans.groupby(["compartment", "outflow_to", "compartment_duration"])[
        ["total_population"]
    ]
    .sum()
    .reset_index()
)
prison_yearly_admission_scale_factor = (
    affected_prison_admissions_per_year / prison_transitions.total_population.sum()
)
prison_transitions.total_population = (
    prison_yearly_admission_scale_factor * prison_transitions.total_population
).round(2)
prison_transitions
# Out:
#    compartment outflow_to  compartment_duration  total_population
# 0       prison    liberty                  15.0             18.49
# 1       prison    liberty                  16.0             18.49
# 2       prison    liberty                  31.0             18.49
# 3       prison    liberty                  59.0             32.58
# 4       prison    liberty                  65.0             32.58
# 5       prison    liberty                 118.0             18.24
# 6       prison    liberty                 123.0             32.58
# 7       prison    liberty                 130.0             18.24
# 8       prison    liberty                 221.0              7.85
# 9       prison    liberty                 244.0              7.85
# 10      prison    liberty                 246.0             18.24
# 11      prison    liberty                 369.0              2.51
# 12      prison    liberty                 406.0              2.51
# 13      prison    liberty                 461.0              7.85
# 14      prison    liberty                 480.0             11.75
# 15      prison     parole                   2.0              1.04
# 16      prison     parole                   3.0              0.52
# 17      prison     parole                   7.0             66.91
# 18      prison     parole                   8.0             65.99
# 19      prison     parole                   9.0             42.57
# 20      prison     parole                  10.0             42.21
# 21      prison     parole                  13.0              1.43
# 22      prison     parole                  14.0              0.55
# 23      prison     parole                  18.0              0.51
# 24      prison     parole                  20.0             41.65
# 25      prison     parole                  21.0             65.99
# 26      prison     parole                  22.0              0.55
# 27      prison     parole                  25.0              0.22
# 28      prison     parole                  26.0            116.79
# 29      prison     parole                  31.0            116.28
# 30      prison     parole                  34.0              0.22
# 31      prison     parole                  35.0             73.39
# 32      prison     parole                  40.0             74.36
# 33      prison     parole                  41.0              0.07
# 34      prison     parole                  48.0              0.22
# 35      prison     parole                  53.0             65.11
# 36      prison     parole                  54.0              0.98
# 37      prison     parole                  57.0              0.07
# 38      prison     parole                  58.0              0.03
# 39      prison     parole                  62.0             65.11
# 40      prison     parole                  70.0             41.09
# 41      prison     parole                  78.0             73.39
# 42      prison     parole                  80.0             41.74
# 43      prison     parole                  83.0              0.02
# 44      prison     parole                  84.0            116.28
# 45      prison     parole                  89.0              0.98
# 46      prison     parole                  99.0             28.01
# 47      prison     parole                 109.0              0.55
# 48      prison     parole                 112.0              0.03
# 49      prison     parole                 115.0              0.02
# 50      prison     parole                 116.0             28.01
# 51      prison     parole                 131.0             17.68
# 52      prison     parole                 132.0              0.03
# 53      prison     parole                 150.0             17.68
# 54      prison     parole                 151.0              0.24
# 55      prison     parole                 156.0             41.09
# 56      prison     parole                 160.0              0.02
# 57      prison     parole                 166.0              8.97
# 58      prison     parole                 167.0             65.11
# 59      prison     parole                 177.0              0.55
# 60      prison     parole                 183.0              0.03
# 61      prison     parole                 193.0              8.97
# 62      prison     parole                 204.0              0.24
# 63      prison     parole                 219.0              5.66
# 64      prison     parole                 232.0              4.15
# 65      prison     parole                 250.0              5.66
# 66      prison     parole                 251.0              0.08
# 67      prison     parole                 255.0              0.03
# 68      prison     parole                 270.0              4.15
# 69      prison     parole                 293.0             17.68
# 70      prison     parole                 306.0              2.62
# 71      prison     parole                 314.0             28.01
# 72      prison     parole                 331.0              2.58
# 73      prison     parole                 332.0              0.24
# 74      prison     parole                 340.0              0.08
# 75      prison     parole                 350.0              2.62
# 76      prison     parole                 352.0              0.03
# 77      prison     parole                 385.0              2.58
# 78      prison     parole                 437.0              1.63
# 79      prison     parole                 477.0              0.03
# 80      prison     parole                 480.0             48.34

# %%
np.average(
    prison_transitions.compartment_duration, weights=prison_transitions.total_population
) / 12
# Out:
# 7.650253915093606

# %%
parole_trans = trans_affected[trans_affected.parole_los > 0][
    ["crime_type", "parole_los", "total_population"]
].copy()
parole_trans["compartment"] = "parole"
parole_trans["outflow_to"] = "liberty"
parole_trans = parole_trans.rename(columns={"parole_los": "compartment_duration"})
parole_trans.compartment_duration = parole_trans.compartment_duration.clip(
    upper=40 * 12
)

# %%
parole_transitions = (
    parole_trans.groupby(["compartment", "outflow_to", "compartment_duration"])[
        ["total_population"]
    ]
    .sum()
    .reset_index()
)

# rough scale factor for readability
yearly_admission_scale_factor = (
    affected_prison_admissions_per_year / parole_transitions.total_population.sum()
)
parole_transitions.total_population = (
    yearly_admission_scale_factor * parole_transitions.total_population
).round(2)
parole_transitions
# Out:
#    compartment outflow_to  compartment_duration  total_population
# 0       parole    liberty                   3.0              0.65
# 1       parole    liberty                   5.0              0.65
# 2       parole    liberty                   6.0             97.47
# 3       parole    liberty                   8.0             77.22
# 4       parole    liberty                   9.0             77.87
# 5       parole    liberty                  10.0             77.22
# 6       parole    liberty                  11.0             49.88
# 7       parole    liberty                  13.0              0.61
# 8       parole    liberty                  14.0              0.61
# 9       parole    liberty                  19.0              1.14
# 10      parole    liberty                  21.0              0.64
# 11      parole    liberty                  24.0             85.87
# 12      parole    liberty                  25.0             85.87
# 13      parole    liberty                  28.0              0.61
# 14      parole    liberty                  33.0            136.06
# 15      parole    liberty                  34.0            137.20
# 16      parole    liberty                  38.0              0.64
# 17      parole    liberty                  39.0            136.33
# 18      parole    liberty                  45.0             85.87
# 19      parole    liberty                  48.0             48.08
# 20      parole    liberty                  50.0             48.08
# 21      parole    liberty                  52.0              1.07
# 22      parole    liberty                  56.0              1.07
# 23      parole    liberty                  65.0             76.19
# 24      parole    liberty                  66.0              0.09
# 25      parole    liberty                  68.0             76.83
# 26      parole    liberty                  70.0              0.28
# 27      parole    liberty                  78.0             76.19
# 28      parole    liberty                  89.0             48.08
# 29      parole    liberty                  90.0             20.69
# 30      parole    liberty                  92.0              0.04
# 31      parole    liberty                  94.0             20.69
# 32      parole    liberty                 105.0              0.60
# 33      parole    liberty                 110.0              1.07
# 34      parole    liberty                 112.0              0.60
# 35      parole    liberty                 117.0              0.09
# 36      parole    liberty                 122.0             32.78
# 37      parole    liberty                 128.0             33.05
# 38      parole    liberty                 132.0              0.03
# 39      parole    liberty                 146.0             32.78
# 40      parole    liberty                 150.0              6.63
# 41      parole    liberty                 156.0              6.63
# 42      parole    liberty                 164.0              0.04
# 43      parole    liberty                 167.0             20.69
# 44      parole    liberty                 196.0              0.26
# 45      parole    liberty                 203.0             10.50
# 46      parole    liberty                 209.0              0.26
# 47      parole    liberty                 210.0              3.07
# 48      parole    liberty                 211.0              0.04
# 49      parole    liberty                 213.0              0.09
# 50      parole    liberty                 214.0             10.50
# 51      parole    liberty                 219.0              3.07
# 52      parole    liberty                 220.0              0.60
# 53      parole    liberty                 234.0              0.03
# 54      parole    liberty                 244.0             10.50
# 55      parole    liberty                 279.0              6.63
# 56      parole    liberty                 284.0              4.86
# 57      parole    liberty                 299.0              4.90
# 58      parole    liberty                 300.0              1.91
# 59      parole    liberty                 313.0              1.91
# 60      parole    liberty                 327.0              0.08
# 61      parole    liberty                 342.0              4.86
# 62      parole    liberty                 349.0              0.08
# 63      parole    liberty                 375.0              0.04
# 64      parole    liberty                 390.0              3.07
# 65      parole    liberty                 406.0              3.02
# 66      parole    liberty                 413.0              0.26
# 67      parole    liberty                 427.0              3.04
# 68      parole    liberty                 458.0              0.04
# 69      parole    liberty                 480.0             29.67

# %%
np.average(
    parole_transitions.compartment_duration, weights=parole_transitions.total_population
) / 12
# Out:
# 5.26481155143915

# %% [markdown]
# ### probation trans

# %%
# pulling felony probation sentence lengths from TX DOC reports
# evenly distributed within buckets, 10 year max
probation_trans = pd.read_csv("input_data/TX Gun MM Raw Data - probation_los.csv")
probation_trans["compartment"] = "probation"
probation_trans["outflow_to"] = "liberty"
probation_trans = probation_trans.rename(columns={"probation_pop": "total_population"})
probation_trans.compartment_duration = 12 * probation_trans.compartment_duration
probation_trans
# Out:
#     compartment_duration  total_population compartment outflow_to
# 0                    6.0           139.500   probation    liberty
# 1                   12.0           139.500   probation    liberty
# 2                   18.0         11338.375   probation    liberty
# 3                   24.0         11338.375   probation    liberty
# 4                   30.0         11338.375   probation    liberty
# 5                   36.0         11338.375   probation    liberty
# 6                   42.0         11338.375   probation    liberty
# 7                   48.0         11338.375   probation    liberty
# 8                   54.0         11338.375   probation    liberty
# 9                   60.0         11338.375   probation    liberty
# 10                  66.0          4893.200   probation    liberty
# 11                  72.0          4893.200   probation    liberty
# 12                  78.0          4893.200   probation    liberty
# 13                  84.0          4893.200   probation    liberty
# 14                  90.0          4893.200   probation    liberty
# 15                  96.0          4893.200   probation    liberty
# 16                 102.0          4893.200   probation    liberty
# 17                 108.0          4893.200   probation    liberty
# 18                 114.0          4893.200   probation    liberty
# 19                 120.0          4893.200   probation    liberty

# %%
transitions = pd.concat([prison_transitions, parole_transitions, probation_trans])
transitions["crime_type"] = "gun"

# %%
manual_row = ["liberty", "liberty", 1.0, 1.0, "gun"]
transitions.loc[len(transitions)] = manual_row

# %%
transitions
# Out:
#     compartment outflow_to  compartment_duration  total_population crime_type
# 0        prison    liberty                  15.0            18.490        gun
# 1        prison    liberty                  16.0            18.490        gun
# 2        prison    liberty                  31.0            18.490        gun
# 3        prison    liberty                  59.0            32.580        gun
# 4        prison    liberty                  65.0            32.580        gun
# 5        prison    liberty                 118.0            18.240        gun
# 6        prison    liberty                 123.0            32.580        gun
# 7        prison    liberty                 130.0            18.240        gun
# 8        prison    liberty                 221.0             7.850        gun
# 9        prison    liberty                 244.0             7.850        gun
# 10       prison    liberty                 246.0            18.240        gun
# 11       prison    liberty                 369.0             2.510        gun
# 12       prison    liberty                 406.0             2.510        gun
# 13       prison    liberty                 461.0             7.850        gun
# 14       prison    liberty                 480.0            11.750        gun
# 15       prison     parole                   2.0             1.040        gun
# 16       prison     parole                   3.0             0.520        gun
# 17       prison     parole                   7.0            66.910        gun
# 18       prison     parole                   8.0            65.990        gun
# 19       prison     parole                   9.0            42.570        gun
# 20       prison     parole                  10.0            42.210        gun
# 21       prison     parole                  13.0             1.430        gun
# 22       prison     parole                  14.0             0.550        gun
# 23       prison     parole                  18.0             0.510        gun
# 24       prison     parole                  20.0            41.650        gun
# 25       prison     parole                  21.0            65.990        gun
# 26       prison     parole                  22.0             0.550        gun
# 27       prison     parole                  25.0             0.220        gun
# 28       prison     parole                  26.0           116.790        gun
# 29       prison     parole                  31.0           116.280        gun
# 30       prison     parole                  34.0             0.220        gun
# 31       prison     parole                  35.0            73.390        gun
# 32       prison     parole                  40.0            74.360        gun
# 33       prison     parole                  41.0             0.070        gun
# 34       prison     parole                  48.0             0.220        gun
# 35       prison     parole                  53.0            65.110        gun
# 36       prison     parole                  54.0             0.980        gun
# 37       prison     parole                  57.0             0.070        gun
# 38       prison     parole                  58.0             0.030        gun
# 39       prison     parole                  62.0            65.110        gun
# 40       prison     parole                  70.0            41.090        gun
# 41       prison     parole                  78.0            73.390        gun
# 42       prison     parole                  80.0            41.740        gun
# 43       prison     parole                  83.0             0.020        gun
# 44       prison     parole                  84.0           116.280        gun
# 45       prison     parole                  89.0             0.980        gun
# 46       prison     parole                  99.0            28.010        gun
# 47       prison     parole                 109.0             0.550        gun
# 48       prison     parole                 112.0             0.030        gun
# 49       prison     parole                 115.0             0.020        gun
# 50       prison     parole                 116.0            28.010        gun
# 51       prison     parole                 131.0            17.680        gun
# 52       prison     parole                 132.0             0.030        gun
# 53       prison     parole                 150.0            17.680        gun
# 54       prison     parole                 151.0             0.240        gun
# 43       parole    liberty                 167.0            20.690        gun
# 44       parole    liberty                 196.0             0.260        gun
# 45       parole    liberty                 203.0            10.500        gun
# 46       parole    liberty                 209.0             0.260        gun
# 47       parole    liberty                 210.0             3.070        gun
# 48       parole    liberty                 211.0             0.040        gun
# 49       parole    liberty                 213.0             0.090        gun
# 50       parole    liberty                 214.0            10.500        gun
# 51       parole    liberty                 219.0             3.070        gun
# 52       parole    liberty                 220.0             0.600        gun
# 53       parole    liberty                 234.0             0.030        gun
# 54       parole    liberty                 244.0            10.500        gun
# 55       parole    liberty                 279.0             6.630        gun
# 56       parole    liberty                 284.0             4.860        gun
# 57       parole    liberty                 299.0             4.900        gun
# 58       parole    liberty                 300.0             1.910        gun
# 59       parole    liberty                 313.0             1.910        gun
# 60       parole    liberty                 327.0             0.080        gun
# 61       parole    liberty                 342.0             4.860        gun
# 62       parole    liberty                 349.0             0.080        gun
# 63       parole    liberty                 375.0             0.040        gun
# 64       parole    liberty                 390.0             3.070        gun
# 65       parole    liberty                 406.0             3.020        gun
# 66       parole    liberty                 413.0             0.260        gun
# 67       parole    liberty                 427.0             3.040        gun
# 68       parole    liberty                 458.0             0.040        gun
# 69       parole    liberty                 480.0            29.670        gun
# 0     probation    liberty                   6.0           139.500        gun
# 1     probation    liberty                  12.0           139.500        gun
# 2     probation    liberty                  18.0         11338.375        gun
# 3     probation    liberty                  24.0         11338.375        gun
# 4     probation    liberty                  30.0         11338.375        gun
# 5     probation    liberty                  36.0         11338.375        gun
# 6     probation    liberty                  42.0         11338.375        gun
# 7     probation    liberty                  48.0         11338.375        gun
# 8     probation    liberty                  54.0         11338.375        gun
# 9     probation    liberty                  60.0         11338.375        gun
# 10    probation    liberty                  66.0          4893.200        gun
# 11    probation    liberty                  72.0          4893.200        gun
# 12    probation    liberty                  78.0          4893.200        gun
# 13    probation    liberty                  84.0          4893.200        gun
# 14    probation    liberty                  90.0          4893.200        gun
# 15    probation    liberty                  96.0          4893.200        gun
# 16    probation    liberty                 102.0          4893.200        gun
# 17    probation    liberty                 108.0          4893.200        gun
# 18    probation    liberty                 114.0          4893.200        gun
# 19    probation    liberty                 120.0          4893.200        gun
# 171     liberty    liberty                   1.0             1.000        gun

# %% [markdown]
# ### Policy Transitions

# %%
alt_transitions = transitions.copy()
alt_transitions.compartment_duration = alt_transitions.compartment_duration.mask(
    (alt_transitions.compartment == "prison")
    | (alt_transitions.compartment == "probation"),
    alt_transitions.compartment_duration.clip(lower=120),
)
alt_transitions = (
    alt_transitions.groupby(["compartment", "outflow_to", "compartment_duration"])[
        ["total_population"]
    ]
    .sum()
    .reset_index()
)
alt_transitions["crime_type"] = "gun"

# manual_row = ["probation", "liberty", 1.0, 1.0,'gun']
# alt_transitions.loc[len(alt_transitions)] = manual_row
alt_transitions
# Out:
#     compartment outflow_to  compartment_duration  total_population crime_type
# 0       liberty    liberty                   1.0              1.00        gun
# 1        parole    liberty                   3.0              0.65        gun
# 2        parole    liberty                   5.0              0.65        gun
# 3        parole    liberty                   6.0             97.47        gun
# 4        parole    liberty                   8.0             77.22        gun
# 5        parole    liberty                   9.0             77.87        gun
# 6        parole    liberty                  10.0             77.22        gun
# 7        parole    liberty                  11.0             49.88        gun
# 8        parole    liberty                  13.0              0.61        gun
# 9        parole    liberty                  14.0              0.61        gun
# 10       parole    liberty                  19.0              1.14        gun
# 11       parole    liberty                  21.0              0.64        gun
# 12       parole    liberty                  24.0             85.87        gun
# 13       parole    liberty                  25.0             85.87        gun
# 14       parole    liberty                  28.0              0.61        gun
# 15       parole    liberty                  33.0            136.06        gun
# 16       parole    liberty                  34.0            137.20        gun
# 17       parole    liberty                  38.0              0.64        gun
# 18       parole    liberty                  39.0            136.33        gun
# 19       parole    liberty                  45.0             85.87        gun
# 20       parole    liberty                  48.0             48.08        gun
# 21       parole    liberty                  50.0             48.08        gun
# 22       parole    liberty                  52.0              1.07        gun
# 23       parole    liberty                  56.0              1.07        gun
# 24       parole    liberty                  65.0             76.19        gun
# 25       parole    liberty                  66.0              0.09        gun
# 26       parole    liberty                  68.0             76.83        gun
# 27       parole    liberty                  70.0              0.28        gun
# 28       parole    liberty                  78.0             76.19        gun
# 29       parole    liberty                  89.0             48.08        gun
# 30       parole    liberty                  90.0             20.69        gun
# 31       parole    liberty                  92.0              0.04        gun
# 32       parole    liberty                  94.0             20.69        gun
# 33       parole    liberty                 105.0              0.60        gun
# 34       parole    liberty                 110.0              1.07        gun
# 35       parole    liberty                 112.0              0.60        gun
# 36       parole    liberty                 117.0              0.09        gun
# 37       parole    liberty                 122.0             32.78        gun
# 38       parole    liberty                 128.0             33.05        gun
# 39       parole    liberty                 132.0              0.03        gun
# 40       parole    liberty                 146.0             32.78        gun
# 41       parole    liberty                 150.0              6.63        gun
# 42       parole    liberty                 156.0              6.63        gun
# 43       parole    liberty                 164.0              0.04        gun
# 44       parole    liberty                 167.0             20.69        gun
# 45       parole    liberty                 196.0              0.26        gun
# 46       parole    liberty                 203.0             10.50        gun
# 47       parole    liberty                 209.0              0.26        gun
# 48       parole    liberty                 210.0              3.07        gun
# 49       parole    liberty                 211.0              0.04        gun
# 50       parole    liberty                 213.0              0.09        gun
# 51       parole    liberty                 214.0             10.50        gun
# 52       parole    liberty                 219.0              3.07        gun
# 53       parole    liberty                 220.0              0.60        gun
# 54       parole    liberty                 234.0              0.03        gun
# 55       parole    liberty                 244.0             10.50        gun
# 56       parole    liberty                 279.0              6.63        gun
# 57       parole    liberty                 284.0              4.86        gun
# 58       parole    liberty                 299.0              4.90        gun
# 59       parole    liberty                 300.0              1.91        gun
# 60       parole    liberty                 313.0              1.91        gun
# 61       parole    liberty                 327.0              0.08        gun
# 62       parole    liberty                 342.0              4.86        gun
# 63       parole    liberty                 349.0              0.08        gun
# 64       parole    liberty                 375.0              0.04        gun
# 65       parole    liberty                 390.0              3.07        gun
# 66       parole    liberty                 406.0              3.02        gun
# 67       parole    liberty                 413.0              0.26        gun
# 68       parole    liberty                 427.0              3.04        gun
# 69       parole    liberty                 458.0              0.04        gun
# 70       parole    liberty                 480.0             29.67        gun
# 71       prison    liberty                 120.0            138.87        gun
# 72       prison    liberty                 123.0             32.58        gun
# 73       prison    liberty                 130.0             18.24        gun
# 74       prison    liberty                 221.0              7.85        gun
# 75       prison    liberty                 244.0              7.85        gun
# 76       prison    liberty                 246.0             18.24        gun
# 77       prison    liberty                 369.0              2.51        gun
# 78       prison    liberty                 406.0              2.51        gun
# 79       prison    liberty                 461.0              7.85        gun
# 80       prison    liberty                 480.0             11.75        gun
# 81       prison     parole                 120.0           1172.89        gun
# 82       prison     parole                 131.0             17.68        gun
# 83       prison     parole                 132.0              0.03        gun
# 84       prison     parole                 150.0             17.68        gun
# 85       prison     parole                 151.0              0.24        gun
# 86       prison     parole                 156.0             41.09        gun
# 87       prison     parole                 160.0              0.02        gun
# 88       prison     parole                 166.0              8.97        gun
# 89       prison     parole                 167.0             65.11        gun
# 90       prison     parole                 177.0              0.55        gun
# 91       prison     parole                 183.0              0.03        gun
# 92       prison     parole                 193.0              8.97        gun
# 93       prison     parole                 204.0              0.24        gun
# 94       prison     parole                 219.0              5.66        gun
# 95       prison     parole                 232.0              4.15        gun
# 96       prison     parole                 250.0              5.66        gun
# 97       prison     parole                 251.0              0.08        gun
# 98       prison     parole                 255.0              0.03        gun
# 99       prison     parole                 270.0              4.15        gun
# 100      prison     parole                 293.0             17.68        gun
# 101      prison     parole                 306.0              2.62        gun
# 102      prison     parole                 314.0             28.01        gun
# 103      prison     parole                 331.0              2.58        gun
# 104      prison     parole                 332.0              0.24        gun
# 105      prison     parole                 340.0              0.08        gun
# 106      prison     parole                 350.0              2.62        gun
# 107      prison     parole                 352.0              0.03        gun
# 108      prison     parole                 385.0              2.58        gun
# 109      prison     parole                 437.0              1.63        gun
# 110      prison     parole                 477.0              0.03        gun
# 111      prison     parole                 480.0             48.34        gun
# 112   probation    liberty                 120.0         139918.00        gun

# %%
alt_transitions.to_csv("alternate_transitions_no_probation.csv", index=False)

# %%
simulation_tag
# Out:
# 'tx_gun_minimums_v1'

# %%
upload_spark_model_inputs(
    project_id="recidiviz-staging",
    simulation_tag=simulation_tag,
    outflows_data_df=outflows,
    transitions_data_df=transitions,
    total_population_data_df=pd.DataFrame(),
    yaml_path=yaml_file_path,
)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 7096.96it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13148.29it/s]

# %%
transitions.groupby(["compartment", "outflow_to", "crime_type"])[
    ["compartment_duration"]
].min()
# Out:
#                                    compartment_duration
# compartment outflow_to crime_type
# liberty     liberty    gun                          1.0
# parole      liberty    gun                          3.0
# prison      liberty    gun                         15.0
#             parole     gun                          2.0
# probation   liberty    gun                          6.0

# %%
alt_transitions.groupby(["compartment", "outflow_to", "crime_type"])[
    ["compartment_duration"]
].min()
# Out:
#                                    compartment_duration
# compartment outflow_to crime_type
# liberty     liberty    gun                          1.0
# parole      liberty    gun                          3.0
# prison      liberty    gun                        120.0
#             parole     gun                        120.0
# probation   liberty    gun                        120.0

# %%
alt_transitions.groupby(["compartment", "outflow_to", "crime_type"])[
    ["compartment_duration"]
].max()
# Out:
#                                    compartment_duration
# compartment outflow_to crime_type
# liberty     liberty    gun                          1.0
# parole      liberty    gun                        480.0
# prison      liberty    gun                        480.0
#             parole     gun                        480.0
# probation   liberty    gun                        120.0
