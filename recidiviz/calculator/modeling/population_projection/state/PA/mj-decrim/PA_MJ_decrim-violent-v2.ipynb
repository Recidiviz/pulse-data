# %%
import os
import sys
import matplotlib
import pandas as pd
import pdb
from IPython import get_ipython
from IPython.display import display


is_notebook = True if "script" not in os.getcwd() else False
recidiviz_data_path = "../../../../../../.." + ("/.." if not is_notebook else "")

sys.path.insert(0, os.path.relpath(recidiviz_data_path))

from recidiviz.calculator.modeling.population_projection.super_simulation.super_simulation_factory import (
    SuperSimulationFactory,
)
from recidiviz.calculator.modeling.population_projection.transition_table import (
    TransitionTable,
)
from recidiviz.calculator.modeling.population_projection.shell_compartment import (
    ShellCompartment,
)
from recidiviz.calculator.modeling.population_projection.spark_policy import SparkPolicy
from functools import partial
import yaml
from recidiviz.utils.yaml_dict import YAMLDict

# %%
# Get the simulation tag from the model inputs config
yaml_file_path = (
    "../" if not is_notebook else ""
) + "pa_mj_decrim_model_inputs_violent_v2.yaml"

simulation_config = YAMLDict.from_path(yaml_file_path)
data_inputs = simulation_config.pop_dict("data_inputs")
simulation_tag = data_inputs.pop("big_query_simulation_tag", str)

# %%
simulation_tag
# Out:
# 'pa_mj_decrim_2022_violent_v2'

# %%
if (is_notebook):
    get_ipython().run_line_magic('run', recidiviz_data_path + "/../recidiviz-research/utils/research_utils.py")
    adjust_plot_scale(0.4)

# %%
policy_sim = SuperSimulationFactory.build_super_simulation(yaml_file_path)
# Out:
# Downloading: 100%|██████████████████████████████████████████████████| 1085/1085 [00:00<00:00, 2598.08rows/s]
# Downloading: 100%|████████████████████████████████████████████████████| 973/973 [00:00<00:00, 3536.33rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████| 328/328 [00:00<00:00, 753.11rows/s]

# %%
transitions_table_violent_post_policy = pd.read_csv(
    ("../" if not is_notebook else "") + "transitions_table_violent.csv"
)

# %%
## Policy functions


def bypass_system(compartment: str):
    return partial(
        ShellCompartment.reallocate_outflow,
        reallocation_fraction=1,
        outflow=compartment,
        new_outflow="liberty",
    )


def reallocate_prison_to_no_parole():
    return partial(
        TransitionTable.reallocate_outflow,
        reallocation_df=pd.DataFrame(
            {"outflow": "parole", "affected_fraction": 1, "new_outflow": "liberty"},
            index=[0],
        ),
        reallocation_type="*",
        retroactive=True,
    )


def resentence_policy(outflow, policy_impact_percent):
    return partial(
        TransitionTable.apply_reductions,
        reduction_df=pd.DataFrame(
            {
                "outflow": outflow,
                "affected_fraction": 1,
                "reduction_size": policy_impact_percent / 100,
            },
            index=[0],
        ),
        reduction_type="*",
        retroactive=True,
    )


def reset_violent_transitions_no_mj():
    return partial(
        TransitionTable.use_alternate_transitions_data,
        alternate_historical_transitions=transitions_table_violent_post_policy,
        retroactive=False,
    )

# %%
# Simulate policy starting in July 2023
policy_ts = 41
affected_pretrial_outflow_compartments = ["prison", "jail", "probation"]
affected_full_compartments = ["prison", "jail", "probation", "parole"]
all_compartments = ["pretrial", "prison", "jail", "probation", "parole"]

# %%
policy_list_violent_and_more_less_serious = (
    ##################################
    # crime_type = has_violent_offense
    ##################################
    [
        # 1 transition table switch
        SparkPolicy(
            policy_fn=reset_violent_transitions_no_mj(),
            spark_compartment=compartment,
            sub_population={"crime_type": "has_violent_offense"},
            policy_ts=policy_ts,
            apply_retroactive=False,
        )
        for compartment in ["prison", "jail", "probation", "parole"]
    ]
    ######################################
    # crime_type = only_mj
    ######################################
    + [
        # 3 shell reallocates to bypass system
        # pretrial -> *
        # now
        # pretrial -> liberty
        SparkPolicy(
            policy_fn=bypass_system(compartment),
            spark_compartment="pretrial",
            sub_population={"crime_type": "only_mj"},
            policy_ts=policy_ts,
            apply_retroactive=False,
        )
        for compartment in ["prison", "jail", "probation"]
    ]
    + [
        # 1 transition reallocate
        # prison -> parole
        # now
        # prison -> liberty
        SparkPolicy(
            policy_fn=reallocate_prison_to_no_parole(),
            spark_compartment="prison",
            sub_population={"crime_type": "only_mj"},
            policy_ts=policy_ts,
            apply_retroactive=True,
        )
    ]
    + [
        # 4 transition reductions
        # * -> liberty immediately
        SparkPolicy(
            policy_fn=resentence_policy("liberty", 100),
            spark_compartment=compartment,
            sub_population={"crime_type": "only_mj"},
            policy_ts=policy_ts,
            apply_retroactive=True,
        )
        for compartment in ["prison", "jail", "probation", "parole"]
    ]
    ######################################
    # crime_type = nv_mj_plus_less_serious
    ######################################
    + [
        # 4 transition reductions (* -> liberty)
        SparkPolicy(
            policy_fn=resentence_policy("liberty", 75),
            spark_compartment=compartment,
            sub_population={"crime_type": "nv_mj_plus_less_serious"},
            policy_ts=policy_ts,
            apply_retroactive=True,
        )
        for compartment in affected_full_compartments
    ]
    + [
        # 1 more transition reduction (prison -> parole)
        SparkPolicy(
            policy_fn=resentence_policy("parole", 75),
            spark_compartment="prison",
            sub_population={"crime_type": "nv_mj_plus_less_serious"},
            policy_ts=policy_ts,
            apply_retroactive=True,
        )
    ]
    ######################################
    # crime_type = nv_mj_plus_more_serious
    ######################################
    + [
        # 4 transition reductions (* -> liberty)
        SparkPolicy(
            policy_fn=resentence_policy("liberty", 25),
            spark_compartment=compartment,
            sub_population={"crime_type": "nv_mj_plus_more_serious"},
            policy_ts=policy_ts,
            apply_retroactive=True,
        )
        for compartment in affected_full_compartments
    ]
    + [
        # 1 more transition reduction (prison -> parole)
        SparkPolicy(
            policy_fn=resentence_policy("parole", 25),
            spark_compartment="prison",
            sub_population={"crime_type": "nv_mj_plus_more_serious"},
            policy_ts=policy_ts,
            apply_retroactive=True,
        )
    ]
)

# %%
policy_results = policy_sim.simulate_policy(
    policy_list_violent_and_more_less_serious, "probation"
)
policy_results["population_difference"] = (
    policy_results["policy_total_population"]
    - policy_results["control_total_population"]
)
# Out:
# /Users/jazz/Recidiviz/pulse-data/recidiviz/calculator/modeling/population_projection/state/PA/mj-decrim/../../../../../../../recidiviz/calculator/modeling/population_projection/population_simulation/population_simulation_factory.py:168: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for (simulation_group_name), _ in transitions_data.groupby(disaggregation_axes):
# initialization time:  7.6811792850494385
# /Users/jazz/Recidiviz/pulse-data/recidiviz/calculator/modeling/population_projection/state/PA/mj-decrim/../../../../../../../recidiviz/calculator/modeling/population_projection/population_simulation/population_simulation_factory.py:168: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for (simulation_group_name), _ in transitions_data.groupby(disaggregation_axes):
# initialization time:  7.290511846542358
# simulation_time:  9.506998062133789
# simulation_time:  8.944550275802612
# 2258.3
# /Users/jazz/Recidiviz/pulse-data/recidiviz/calculator/modeling/population_projection/state/PA/mj-decrim/../../../../../../../recidiviz/calculator/modeling/population_projection/super_simulation/simulator.py:288: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   simulation_results = simulation_results.groupby(

# %%
simulation_tag
# Out:
# 'pa_mj_decrim_2022_violent_v2'

# %%
results_dict = policy_sim.upload_policy_simulation_results_to_bq(simulation_tag)
# Out:
# /Users/jazz/Recidiviz/pulse-data/recidiviz/calculator/modeling/population_projection/state/PA/mj-decrim/../../../../../../../recidiviz/calculator/modeling/population_projection/super_simulation/exporter.py:100: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   output_data["policy_simulation"]
# 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 9510.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 5745.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 8128.50it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 3377.06it/s]

# %%
total_population_data = policy_sim.initializer.data_inputs.total_population_data.copy()
total_population_data[
    "year"
] = policy_sim.initializer.time_converter.convert_time_steps_to_year(
    total_population_data["time_step"]
)
total_population_data = total_population_data.set_index(
    ["crime_type", "compartment", "year"]
).sort_index()["total_population"]

for compartment, results in policy_results.groupby(["compartment"]):
    plt.figure()
    ax = None
    if compartment in total_population_data.index.get_level_values("compartment"):
        ax = (
            total_population_data[
                total_population_data.index.get_level_values("compartment")
                == compartment
            ]
            .groupby("year")
            .sum()
            .plot(label="input_population")
        )
    results.groupby("year")[
        ["policy_total_population", "control_total_population"]
    ].sum().plot(ax=ax)
    add_legend()
    plt.ylim(0)
    plt.title(f"{compartment}")
# Out:
# /var/folders/jn/2ddz89hx6tjf4m3dvz3dch840000gn/T/ipykernel_69820/3066392526.py:11: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for compartment, results in policy_results.groupby(["compartment"]):

# %%
x = 1
for group, results in policy_results.groupby(["simulation_group", "compartment"]):
    plt.figure(x)
    plt.plot(results[["policy_total_population", "control_total_population"]])
    plt.title(f"{group}")
    x += 1
#     policy_results.reset_index().pivot(index='year',columns=['simulation_group','compartment'],values=['policy_total_population','control_total_population']).plot()

# %%
x = 1
for group, results in policy_results.groupby(["simulation_group", "compartment"]):
    #     display(results.head())
    plt.figure(x)
    #     print(group)
    #     display(
    #         pd.concat(
    #             [
    #                 results.sort_values("control_total_population", ascending=False).head(
    #                     1
    #                 ),
    #                 results.sort_values("control_total_population", ascending=False).head(
    #                     1
    #                 ),
    #             ]
    #         )
    #     )
    #     print(f"maxes at ")
    plt.plot(results[["policy_total_population", "control_total_population"]])
    plt.title(f"{group}")
    x += 1
#     policy_results.reset_index().pivot(index='year',columns=['simulation_group','compartment'],values=['policy_total_population','control_total_population']).plot()

# %%
policy_results[(policy_results.index > 2022.9) & (policy_results.index <= 2022.99)]
# Out:
#             compartment  policy_total_population         simulation_group  \
# year
# 2022.916667      prison                23.666875      has_violent_offense
# 2022.916667      parole                31.521385      has_violent_offense
# 2022.916667        jail                 1.442916      has_violent_offense
# 2022.916667   probation                39.727886      has_violent_offense
# 2022.916667     liberty               462.098969      has_violent_offense
# 2022.916667      prison                 6.989258  nv_mj_plus_less_serious
# 2022.916667      parole                13.999947  nv_mj_plus_less_serious
# 2023.916667                133.981846            -104.545497
# 2023.916667               1995.320027             122.777338
# 2023.916667                 97.614609             -28.650216
# 2023.916667                157.620953             -30.071622
# 2023.916667                 16.649347              -4.056271
# 2023.916667                315.971789             -88.346979
# 2023.916667               8013.685425             151.125003
# 2023.916667                 16.554665             -16.554665
# 2023.916667                 24.700729             -24.700729
# 2023.916667                 93.772834             -93.772834
# 2023.916667                599.881212            -599.881212
# 2023.916667              21127.315797             734.909496

# %%
policy_results[
    (policy_results.index > 2022.9) & (policy_results.index <= 2022.99)
].groupby("compartment").sum()
# Out:
# /var/folders/jn/2ddz89hx6tjf4m3dvz3dch840000gn/T/ipykernel_67227/3598819476.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   policy_results[
#              policy_total_population  control_total_population  \
# compartment
# jail                      115.880342                115.880342
# liberty                 30364.964919              30364.964919
# parole                    253.886670                253.886670
# prison                    156.663064                156.663064
# probation                1221.163715               1221.163715
#
#              population_difference
# compartment
# jail                           0.0
# liberty                        0.0
# parole                         0.0
# prison                         0.0
# probation                      0.0

# %%
policy_results[(policy_results.compartment == "prison") & (policy_results.index < 2024)]
# Out:
#             compartment  policy_total_population         simulation_group  \
# year
# 2020.000000      prison                34.771035      has_violent_offense
# 2020.083333      prison                34.637734      has_violent_offense
# 2020.166667      prison                34.338037      has_violent_offense
# 2020.250000      prison                34.172147      has_violent_offense
# 2020.333333      prison                34.124910      has_violent_offense
# 2020.416667      prison                34.086922      has_violent_offense
# 2020.500000      prison                33.953215      has_violent_offense
# 2020.583333      prison                33.806309      has_violent_offense
# 2020.666667      prison                33.627022      has_violent_offense
# 2020.750000      prison                33.289373      has_violent_offense
# 2020.833333      prison                32.905953      has_violent_offense
# 2020.916667      prison                32.771358      has_violent_offense
# 2021.000000      prison                32.434223      has_violent_offense
# 2021.083333      prison                32.142709      has_violent_offense
# 2021.166667      prison                31.748757      has_violent_offense
# 2021.250000      prison                31.365743      has_violent_offense
# 2021.333333      prison                30.990091      has_violent_offense
# 2021.416667      prison                30.498228      has_violent_offense
# 2021.500000      prison                30.204893      has_violent_offense
# 2021.583333      prison                29.827938      has_violent_offense
# 2021.666667      prison                29.494974      has_violent_offense
# 2021.750000      prison                29.026114      has_violent_offense
# 2021.833333      prison                28.742525      has_violent_offense
# 2021.916667      prison                28.452327      has_violent_offense
# 2022.000000      prison                27.922385      has_violent_offense
# 2022.083333      prison                27.283712      has_violent_offense
# 2022.166667      prison                26.858241      has_violent_offense
# 2022.250000      prison                26.410482      has_violent_offense
# 2022.333333      prison                25.940991      has_violent_offense
# 2022.416667      prison                25.639530      has_violent_offense
# 2022.500000      prison                25.358793      has_violent_offense
# 2022.583333      prison                25.117473      has_violent_offense
# 2022.666667      prison                24.710117      has_violent_offense
# 2022.750000      prison                24.399903      has_violent_offense
# 2022.833333      prison                23.965746      has_violent_offense
# 2022.916667      prison                23.666875      has_violent_offense
# 2023.000000      prison                23.278367      has_violent_offense
# 2023.083333      prison                22.917002      has_violent_offense
# 2023.166667      prison                22.662172      has_violent_offense
# 2023.250000      prison                22.365845      has_violent_offense
# 2023.416667                 16.518518             -16.518518
# 2023.500000                 16.538885             -16.538885
# 2023.583333                 16.533860             -16.533860
# 2023.666667                 16.534908             -16.534908
# 2023.750000                 16.544803             -16.544803
# 2023.833333                 16.550893             -16.550893
# 2023.916667                 16.554665             -16.554665

# %%
from IPython.display import display

policy_results[
    (policy_results.index > 2022.9) & (policy_results.index <= 2022.99)
].sort_values(["simulation_group"])
# Out:
#             compartment  policy_total_population         simulation_group  \
# year
# 2022.916667      prison                23.666875      has_violent_offense
# 2022.916667      parole                31.521385      has_violent_offense
# 2022.916667        jail                 1.442916      has_violent_offense
# 2022.916667   probation                39.727886      has_violent_offense
# 2022.916667     liberty               462.098969      has_violent_offense
# 2022.916667   probation               159.286004  nv_mj_plus_less_serious
# 2022.916667        jail                 7.291250  nv_mj_plus_less_serious
# 2022.916667     liberty              1900.716981  nv_mj_plus_less_serious
# 2022.916667      prison                 6.989258  nv_mj_plus_less_serious
# 2022.916667      parole                13.999947  nv_mj_plus_less_serious
# 2022.916667      prison               109.464768  nv_mj_plus_more_serious
# 2022.916667      parole               178.130570  nv_mj_plus_more_serious
# 2022.916667        jail                16.109253  nv_mj_plus_more_serious
# 2022.916667   probation               332.143068  nv_mj_plus_more_serious
# 2022.916667     liberty              7659.784411  nv_mj_plus_more_serious
# 2022.916667   probation               690.006758                  only_mj
# 2022.916667      prison                16.542162                  only_mj
# 2022.916667      parole                30.234768                  only_mj
# 2022.916667        jail                91.036923                  only_mj
# 2022.916667     liberty             20342.364557                  only_mj
#
#              control_total_population  population_difference
# year
# 2022.916667                 23.666875                    0.0
# 2022.916667                 31.521385                    0.0
# 2022.916667                  1.442916                    0.0
# 2022.916667                 39.727886                    0.0
# 2022.916667                462.098969                    0.0
# 2022.916667                159.286004                    0.0
# 2022.916667                  7.291250                    0.0
# 2022.916667               1900.716981                    0.0
# 2022.916667                  6.989258                    0.0
# 2022.916667                 13.999947                    0.0
# 2022.916667                109.464768                    0.0
# 2022.916667                178.130570                    0.0
# 2022.916667                 16.109253                    0.0
# 2022.916667                332.143068                    0.0
# 2022.916667               7659.784411                    0.0
# 2022.916667                690.006758                    0.0
# 2022.916667                 16.542162                    0.0
# 2022.916667                 30.234768                    0.0
# 2022.916667                 91.036923                    0.0
# 2022.916667              20342.364557                    0.0

# %%
policy_results.head()
# Out:
#             compartment  policy_total_population     simulation_group  \
# year
# 2020.000000      prison                34.771035  has_violent_offense
# 2020.083333      prison                34.637734  has_violent_offense
# 2020.166667      prison                34.338037  has_violent_offense
# 2020.250000      prison                34.172147  has_violent_offense
# 2020.333333      prison                34.124910  has_violent_offense
#
#              control_total_population  population_difference
# year
# 2020.000000                 34.771035                    0.0
# 2020.083333                 34.637734                    0.0
# 2020.166667                 34.338037                    0.0
# 2020.250000                 34.172147                    0.0
# 2020.333333                 34.124910                    0.0

# %%
policy_sim.initializer.data_inputs.total_population_data.head()
# Out:
#                  simulation_tag  time_step compartment  total_population  \
# 0  pa_mj_decrim_2022_violent_v2        -12        jail             100.0
# 1  pa_mj_decrim_2022_violent_v2         -2        jail             108.0
# 2  pa_mj_decrim_2022_violent_v2        -25        jail             120.0
# 3  pa_mj_decrim_2022_violent_v2        -14        jail             120.0
# 4  pa_mj_decrim_2022_violent_v2        -20        jail             136.0
#
#   crime crime_type   age  race                     date_created
# 0  None    only_mj  None  None 2022-12-09 13:59:15.229709+00:00
# 1  None    only_mj  None  None 2022-12-09 13:59:15.229709+00:00
# 2  None    only_mj  None  None 2022-12-09 13:59:15.229709+00:00
# 3  None    only_mj  None  None 2022-12-09 13:59:15.229709+00:00
# 4  None    only_mj  None  None 2022-12-09 13:59:15.229709+00:00

# %%
policy_results.groupby(["compartment", "year", "simulation_group"]).sum().loc[
    "prison", "population_difference"
].unstack("simulation_group").plot()
add_legend()

# %%
policy_results.groupby(["compartment", "year"]).sum()["population_difference"].unstack(
    "compartment"
).plot()
add_legend()
# Out:
# /var/folders/jn/2ddz89hx6tjf4m3dvz3dch840000gn/T/ipykernel_57643/4144902263.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   policy_results.groupby(["compartment", "year"]).sum()["population_difference"].unstack(

# %%
policy_results.groupby(["compartment", "year", "simulation_group"]).sum().loc[
    "prison", "policy_total_population"
].unstack("simulation_group").plot()
# Out:
# <AxesSubplot: xlabel='year'>

# %%
policy_sim.get_arima_output_plots(simulation_title="control", by_simulation_group=True)
# Out:
# /Users/jazz/Recidiviz/pulse-data/recidiviz/calculator/modeling/population_projection/state/PA/mj-decrim/../../../../../../../recidiviz/calculator/modeling/population_projection/population_simulation/population_simulation.py:319: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   arima_output_df = arima_output_df.append(output_df_sub)
# /Users/jazz/Recidiviz/pulse-data/recidiviz/calculator/modeling/population_projection/state/PA/mj-decrim/../../../../../../../recidiviz/calculator/modeling/population_projection/population_simulation/population_simulation.py:319: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   arima_output_df = arima_output_df.append(output_df_sub)
# [<AxesSubplot: title={'left': 'simulation_group: any\ncompartment: pretrial\noutflow_to: jail'}, xlabel='time_step'>,
#  <AxesSubplot: title={'left': 'simulation_group: any\ncompartment: pretrial\noutflow_to: prison'}, xlabel='time_step'>,
#  <AxesSubplot: title={'left': 'simulation_group: any\ncompartment: pretrial\noutflow_to: probation'}, xlabel='time_step'>,
#  <AxesSubplot: title={'left': 'simulation_group: only\ncompartment: pretrial\noutflow_to: jail'}, xlabel='time_step'>,
#  <AxesSubplot: title={'left': 'simulation_group: only\ncompartment: pretrial\noutflow_to: prison'}, xlabel='time_step'>,
#  <AxesSubplot: title={'left': 'simulation_group: only\ncompartment: pretrial\noutflow_to: probation'}, xlabel='time_step'>]

# %%
policy_sim.get_arima_output_plots(
    simulation_title="baseline_projections", by_simulation_group=True
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 policy_sim.get_arima_output_plots(
#       2     simulation_title="baseline_projections", by_simulation_group=True
#       3 )
#
# File ~/Recidiviz/pulse-data/recidiviz/calculator/modeling/population_projection/state/PA/mj-decrim/../../../../../../../recidiviz/calculator/modeling/population_projection/super_simulation/super_simulation.py:231, in SuperSimulation.get_arima_output_plots(self, simulation_title, fig_size, by_simulation_group)
#     225 def get_arima_output_plots(
#     226     self,
#     227     simulation_title: str,
#     228     fig_size: Tuple[int, int] = (8, 6),
#     229     by_simulation_group: bool = False,
#     230 ) -> List[plt.subplot]:
# --> 231     return self.validator.gen_arima_output_plots(
#     232         simulation_title, fig_size, by_simulation_group
#     233     )
#
# File ~/Recidiviz/pulse-data/recidiviz/calculator/modeling/population_projection/state/PA/mj-decrim/../../../../../../../recidiviz/calculator/modeling/population_projection/super_simulation/validator.py:103, in Validator.gen_arima_output_plots(self, simulation_title, fig_size, by_simulation_group)
#      91 def gen_arima_output_plots(
#      92     self,
#      93     simulation_title: str,
#      94     fig_size: Tuple[int, int],
#      95     by_simulation_group: bool,
#      96 ) -> List[plt.subplot]:
#      97     """
#      98     Generates admissions forecast plots broken up by compartment and outflow.
#      99     `simulation_title` should be the tag of the PopulationSimulation of interest
#     100     If by_simulation_group = False, plots are generated for each shell compartment and outflow_to compartment
#     101     If by_simulation_group = True these are further subdivided by simulation group
#     102     """
# --> 103     arima_output_df = self.gen_arima_output_df(simulation_title)
#     104     if not by_simulation_group:
#     105         arima_output_df = arima_output_df.groupby(
#     106             level=["compartment", "outflow_to", "time_step"]
#     107         ).apply(lambda x: x.sum(skipna=False))
#
# File ~/Recidiviz/pulse-data/recidiviz/calculator/modeling/population_projection/state/PA/mj-decrim/../../../../../../../recidiviz/calculator/modeling/population_projection/super_simulation/validator.py:89, in Validator.gen_arima_output_df(self, simulation_title)
#      88 def gen_arima_output_df(self, simulation_title: str) -> pd.DataFrame:
# ---> 89     return self.pop_simulations[simulation_title].gen_arima_output_df()
#
# KeyError: 'baseline_projections'

# %%
policy_sim.simulate_baseline(["prison"])
# Out:
# /Users/justine/.local/share/virtualenvs/pulse-data-xK3VhzVV/lib/python3.8/site-packages/pandas/core/indexing.py:1667: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = value
# initialization time:  7.305008888244629
# simulation_time:  7.180202960968018

# %%
baseline_output = policy_sim.validator.pop_simulations["control"].population_projections
baseline_output.set_index(["compartment", "time_step", "simulation_group"]).loc[
    "prison", "total_population"
].unstack("simulation_group").plot()
add_legend()
plt.title("FED HB 5977 Population Projection")
# Out:
# /var/folders/0j/xkvk5w791vj4vtys8s77jn4w0000gn/T/ipykernel_52609/1323526667.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   baseline_output.set_index(["compartment", "time_step", "simulation_group"]).loc["prison", "total_population"]\
# Text(0.0, 1.0, 'FED HB 5977 Population Projection')

# %%
baseline_outflows = (
    policy_sim.validator.pop_simulations["control"].get_outflows().copy()
)
baseline_outflows[
    "year"
] = policy_sim.initializer.time_converter.convert_time_steps_to_year(
    baseline_outflows.index.get_level_values("time_step")
)
baseline_outflows = baseline_outflows[baseline_outflows["compartment"] != "release"]
baseline_outflows.groupby(["time_step", "compartment", "outflow_to"]).sum()[
    "total_population"
].unstack(["compartment", "outflow_to"]).plot()
add_legend()
plt.title("Baseline Simulation Projected Transitions")
# Out:
# Text(0.0, 1.0, 'Baseline Simulation Projected Transitions')

# %%
policy_outflows = policy_sim.validator.pop_simulations["policy"].get_outflows().copy()
policy_outflows[
    "year"
] = policy_sim.initializer.time_converter.convert_time_steps_to_year(
    policy_outflows.index.get_level_values("time_step")
)
policy_outflows = policy_outflows[policy_outflows["compartment"] != "release"]
policy_outflows.groupby(["time_step", "compartment", "outflow_to"]).sum()[
    "total_population"
].unstack(["compartment", "outflow_to"]).plot()
add_legend()
plt.title("Policy Simulation Projected Transitions")
# Out:
# Text(0.0, 1.0, 'Policy Simulation Projected Transitions')

# %%
policy_outflows[policy_outflows["simulation_group"] == "100"].loc["prison"]
# Out:
#            total_population compartment simulation_group         year
# time_step
# -120             551.166667    pretrial              100  2010.666667
# -119             551.166667    pretrial              100  2010.750000
# -118             551.166667    pretrial              100  2010.833333
# -117             551.166667    pretrial              100  2010.916667
# -116             551.166667    pretrial              100  2011.000000
# ...                     ...         ...              ...          ...
#  143               0.000000    pretrial              100  2032.583333
#  144               0.000000    pretrial              100  2032.666667
#  145               0.000000    pretrial              100  2032.750000
#  146               0.000000    pretrial              100  2032.833333
#  147               0.000000    pretrial              100  2032.916667
#
# [268 rows x 4 columns]

# %%
outflows_diff = baseline_outflows.reset_index(drop=False).merge(
    policy_outflows.reset_index(drop=False),
    how="inner",
    on=["time_step", "outflow_to", "compartment", "simulation_group", "year"],
    suffixes=("_control", "_policy"),
)
outflows_diff["outflows_difference"] = (
    outflows_diff["total_population_policy"] - outflows_diff["total_population_control"]
)
outflows_diff["actual_year"] = np.floor(outflows_diff["year"])
outflows_diff[
    (outflows_diff["compartment"] == "pretrial") & (outflows_diff["year"] >= 2022)
]
# Out:
#      outflow_to  time_step  total_population_control compartment  \
# 136      prison         16                 93.333333    pretrial
# 137      prison         17                 93.333333    pretrial
# 138      prison         18                 93.333333    pretrial
# 139      prison         19                 93.333333    pretrial
# 140      prison         20                 93.333333    pretrial
# ...         ...        ...                       ...         ...
# 1335     prison        143                  6.333333    pretrial
# 1336     prison        144                  6.333333    pretrial
# 1337     prison        145                  6.333333    pretrial
# 1338     prison        146                  6.333333    pretrial
# 1339     prison        147                  6.333333    pretrial
#
#      simulation_group         year  total_population_policy  \
# 136               100  2022.000000                93.333333
# 137               100  2022.083333                93.333333
# 138               100  2022.166667                93.333333
# 139               100  2022.250000                93.333333
# 140               100  2022.333333                93.333333
# ...               ...          ...                      ...
# 1335                5  2032.583333                 6.333333
# 1336                5  2032.666667                 6.333333
# 1337                5  2032.750000                 6.333333
# 1338                5  2032.833333                 6.333333
# 1339                5  2032.916667                 6.333333
#
#       outflows_difference  actual_year
# 136                   0.0       2022.0
# 137                   0.0       2022.0
# 138                   0.0       2022.0
# 139                   0.0       2022.0
# 140                   0.0       2022.0
# ...                   ...          ...
# 1335                  0.0       2032.0
# 1336                  0.0       2032.0
# 1337                  0.0       2032.0
# 1338                  0.0       2032.0
# 1339                  0.0       2032.0
#
# [396 rows x 9 columns]

# %%
outflows_diff.set_index(["outflow_to", "year", "simulation_group"]).loc[
    "prison", "outflows_difference"
].unstack(["simulation_group"]).plot()
# Out:
# /var/folders/0j/xkvk5w791vj4vtys8s77jn4w0000gn/T/ipykernel_58074/1988763416.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   outflows_diff.set_index(["outflow_to", "year", "simulation_group"]
# <AxesSubplot:xlabel='year'>
# WARNING:matplotlib.font_manager:findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Libre Franklin

# %%
outflows_diff.head()
# Out:
#   outflow_to  time_step  total_population_control compartment  \
# 0     prison       -120                551.166667    pretrial
# 1     prison       -119                551.166667    pretrial
# 2     prison       -118                551.166667    pretrial
# 3     prison       -117                551.166667    pretrial
# 4     prison       -116                551.166667    pretrial
#
#   simulation_group         year  total_population_policy  outflows_difference  \
# 0              100  2010.666667               551.166667                  0.0
# 1              100  2010.750000               551.166667                  0.0
# 2              100  2010.833333               551.166667                  0.0
# 3              100  2010.916667               551.166667                  0.0
# 4              100  2011.000000               551.166667                  0.0
#
#    actual_year
# 0       2010.0
# 1       2010.0
# 2       2010.0
# 3       2010.0
# 4       2011.0

# %%
cummulative_outflows_diff = (
    outflows_diff.groupby(["outflow_to", "year"])
    .sum()
    .loc["prison", "outflows_difference"]
    .cumsum()
)
cummulative_outflows_diff.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
cummulative_outflows_diff[
    (cummulative_outflows_diff.index.get_level_values("year") % 1) > 0.9
]
# Out:
# year
# 2010.916667        0.0
# 2011.916667        0.0
# 2012.916667        0.0
# 2013.916667        0.0
# 2014.916667        0.0
# 2015.916667        0.0
# 2016.916667        0.0
# 2017.916667        0.0
# 2018.916667        0.0
# 2019.916667        0.0
# 2020.916667        0.0
# 2021.916667        0.0
# 2022.916667        0.0
# 2023.916667    -1120.0
# 2024.916667    -2240.0
# 2025.916667    -3360.0
# 2026.916667    -4480.0
# 2027.916667    -5600.0
# 2028.916667    -6720.0
# 2029.916667    -7840.0
# 2030.916667    -8960.0
# 2031.916667   -10080.0
# 2032.916667   -11200.0
# Name: outflows_difference, dtype: float64

# %%
outflows_diff[outflows_diff["outflow_to"] == "prison"].groupby("actual_year").sum()[
    "outflows_difference"
]
# Out:
# actual_year
# 2010.0       0.0
# 2011.0       0.0
# 2012.0       0.0
# 2013.0       0.0
# 2014.0       0.0
# 2015.0       0.0
# 2016.0       0.0
# 2017.0       0.0
# 2018.0       0.0
# 2019.0       0.0
# 2020.0       0.0
# 2021.0       0.0
# 2022.0       0.0
# 2023.0   -1120.0
# 2024.0   -1120.0
# 2025.0   -1120.0
# 2026.0   -1120.0
# 2027.0   -1120.0
# 2028.0   -1120.0
# 2029.0   -1120.0
# 2030.0   -1120.0
# 2031.0   -1120.0
# 2032.0   -1120.0
# Name: outflows_difference, dtype: float64

# %%
# %%bigquery transitions_df
# WITH latest_runs AS
# (
# SELECT simulation_tag, MAX(date_created) as latest_run
# FROM `recidiviz-staging.spark_public_input_data.transitions_data_raw`
# GROUP BY simulation_tag
# )
# SELECT data.*
# FROM `recidiviz-staging.spark_public_input_data.transitions_data_raw` data
# LEFT JOIN latest_runs ON data.simulation_tag = latest_runs.simulation_tag
# WHERE data.simulation_tag = 'fed_h5977'
#     AND date_created = latest_runs.latest_run
# ORDER BY compartment, compartment_duration
# Out:
# Query complete after 0.01s: 100%|████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1205.88query/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 305/305 [00:01<00:00, 210.57rows/s]

# %%
transitions_df.set_index(["compartment", "crime_type", "compartment_duration"]).loc[
    "prison"
].unstack("crime_type")["total_population"].plot()
# Out:
# <AxesSubplot:xlabel='compartment_duration'>

# %%
transitions_df.set_index(["compartment", "crime_type", "compartment_duration"]).loc[
    "prison", "5"
]
# Out:
# /var/folders/0j/xkvk5w791vj4vtys8s77jn4w0000gn/T/ipykernel_50343/4077636974.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   transitions_df.set_index(["compartment", "crime_type", "compartment_duration"]
#                      simulation_tag outflow_to  total_population crime   age  \
# compartment_duration
# 0.0                       fed_h5977    release              75.0  None  None
# 1.0                       fed_h5977    release               1.0  None  None
# 2.0                       fed_h5977    release               3.0  None  None
# 3.0                       fed_h5977    release               3.0  None  None
# 4.0                       fed_h5977    release              12.0  None  None
# 5.0                       fed_h5977    release               4.0  None  None
# 6.0                       fed_h5977    release              11.0  None  None
# 8.0                       fed_h5977    release              12.0  None  None
# 9.0                       fed_h5977    release               4.0  None  None
# 10.0                      fed_h5977    release               8.0  None  None
# 11.0                      fed_h5977    release               2.0  None  None
# 12.0                      fed_h5977    release              31.0  None  None
# 13.0                      fed_h5977    release              14.0  None  None
# 14.0                      fed_h5977    release               6.0  None  None
# 15.0                      fed_h5977    release              34.0  None  None
# 16.0                      fed_h5977    release               3.0  None  None
# 17.0                      fed_h5977    release               1.0  None  None
# 18.0                      fed_h5977    release              33.0  None  None
# 19.0                      fed_h5977    release               1.0  None  None
# 20.0                      fed_h5977    release               2.0  None  None
# 21.0                      fed_h5977    release              14.0  None  None
# 23.0                      fed_h5977    release               1.0  None  None
# 24.0                      fed_h5977    release              66.0  None  None
# 26.0                      fed_h5977    release               1.0  None  None
# 27.0                      fed_h5977    release              33.0  None  None
# 30.0                      fed_h5977    release              42.0  None  None
# 33.0                      fed_h5977    release              12.0  None  None
# 36.0                      fed_h5977    release              10.0  None  None
# 37.0                      fed_h5977    release              21.0  None  None
# 40.0                      fed_h5977    release               3.0  None  None
# 41.0                      fed_h5977    release               9.0  None  None
# 42.0                      fed_h5977    release               4.0  None  None
# 44.0                      fed_h5977    release               1.0  None  None
# 45.0                      fed_h5977    release               2.0  None  None
# 46.0                      fed_h5977    release               6.0  None  None
# 48.0                      fed_h5977    release               7.0  None  None
# 50.0                      fed_h5977    release               4.0  None  None
# 51.0                      fed_h5977    release               4.0  None  None
# 52.0                      fed_h5977    release               2.0  None  None
# 53.0                      fed_h5977    release               2.0  None  None
# 54.0                      fed_h5977    release               2.0  None  None
# 55.0                      fed_h5977    release               1.0  None  None
# 57.0                      fed_h5977    release               4.0  None  None
# 60.0                      fed_h5977    release              17.0  None  None
# 61.0                      fed_h5977    release               2.0  None  None
# 63.0                      fed_h5977    release               5.0  None  None
# 64.0                      fed_h5977    release               1.0  None  None
# 70.0                      fed_h5977    release              10.0  None  None
# 71.0                      fed_h5977    release               1.0  None  None
# 72.0                      fed_h5977    release               8.0  None  None
# 77.0                      fed_h5977    release               2.0  None  None
# 138.0                 None 2021-11-18 15:59:00.624130+00:00
# 140.0                 None 2021-11-18 15:59:00.624130+00:00
# 144.0                 None 2021-11-18 15:59:00.624130+00:00
# 150.0                 None 2021-11-18 15:59:00.624130+00:00
# 151.0                 None 2021-11-18 15:59:00.624130+00:00
# 160.0                 None 2021-11-18 15:59:00.624130+00:00
# 168.0                 None 2021-11-18 15:59:00.624130+00:00
# 175.0                 None 2021-11-18 15:59:00.624130+00:00
# 180.0                 None 2021-11-18 15:59:00.624130+00:00
# 181.0                 None 2021-11-18 15:59:00.624130+00:00
# 192.0                 None 2021-11-18 15:59:00.624130+00:00
# 198.0                 None 2021-11-18 15:59:00.624130+00:00
# 200.0                 None 2021-11-18 15:59:00.624130+00:00
# 210.0                 None 2021-11-18 15:59:00.624130+00:00
# 216.0                 None 2021-11-18 15:59:00.624130+00:00
# 255.0                 None 2021-11-18 15:59:00.624130+00:00
# 262.0                 None 2021-11-18 15:59:00.624130+00:00
# 264.0                 None 2021-11-18 15:59:00.624130+00:00
# 270.0                 None 2021-11-18 15:59:00.624130+00:00
# 276.0                 None 2021-11-18 15:59:00.624130+00:00
# 288.0                 None 2021-11-18 15:59:00.624130+00:00
# 300.0                 None 2021-11-18 15:59:00.624130+00:00
# 360.0                 None 2021-11-18 15:59:00.624130+00:00
# 465.0                 None 2021-11-18 15:59:00.624130+00:00
# 511.0                 None 2021-11-18 15:59:00.624130+00:00
# 525.0                 None 2021-11-18 15:59:00.624130+00:00
# 1620.0                None 2021-11-18 15:59:00.624130+00:00
# 1860.0                None 2021-11-18 15:59:00.624130+00:00

# %%
# %%bigquery population_df
# WITH latest_runs AS
# (
# SELECT simulation_tag, MAX(date_created) as latest_run
# FROM `recidiviz-staging.spark_public_input_data.total_population_data_raw`
# GROUP BY simulation_tag
# )
# SELECT data.*
# FROM `recidiviz-staging.spark_public_input_data.total_population_data_raw` data
# LEFT JOIN latest_runs ON data.simulation_tag = latest_runs.simulation_tag
# WHERE data.simulation_tag = 'fed_h5977'
#     AND date_created = latest_runs.latest_run
# ORDER BY time_step
# Out:
# Query complete after 0.00s: 100%|████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2557.50query/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 207/207 [00:01<00:00, 138.26rows/s]

# %%
population_df[
    "year"
] = policy_sim.initializer.time_converter.convert_time_steps_to_year(
    population_df["time_step"]
)

# %%
population_df.set_index(["compartment", "year", "crime_type"]).loc["prison"].unstack(
    "crime_type"
)["total_population"].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
for crime_type in ["20", "5"]:
    ax = (
        population_df[population_df["crime_type"] == crime_type]
        .set_index(["compartment", "year"])
        .loc["prison", "total_population"]
        .plot()
    )

    policy_results[policy_results["simulation_group"] == crime_type].groupby(
        ["compartment", "year"]
    ).sum().loc["prison", ["policy_total_population", "control_total_population"]].plot(
        ax=ax
    )
plt.legend().remove()

# %%
policy_results.tail()
# Out:
#     compartment         year  policy_total_population simulation_group  \
# 715     release  2030.250000              1245.795580                5
# 716     release  2030.333333              1252.128918                5
# 717     release  2030.416667              1258.462257                5
# 718     release  2030.500000              1264.795597                5
# 719     release  2030.583333              1271.128936                5
#
#      control_total_population  population_difference
# 715               1232.633632              13.161947
# 716               1238.627747              13.501171
# 717               1244.626906              13.835352
# 718               1251.085304              13.710293
# 719               1257.275110              13.853826

# %% [markdown]
# # RUN 1 - just prison policies

# %%
policy_results = policy_sim.simulate_policy(policy_list, "prison")
policy_results["population_difference"] = (
    policy_results["policy_total_population"]
    - policy_results["control_total_population"]
)
# Out:
# /Users/jazz/Recidiviz/pulse-data/recidiviz/calculator/modeling/population_projection/state/PA/mj-decrim/../../../../../../../recidiviz/calculator/modeling/population_projection/population_simulation/population_simulation_factory.py:168: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for (simulation_group_name), _ in transitions_data.groupby(disaggregation_axes):
# /Users/jazz/.local/share/virtualenvs/pulse-data-WLwBta1t/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/jazz/.local/share/virtualenvs/pulse-data-WLwBta1t/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# initialization time:  3.6129260063171387
# /Users/jazz/Recidiviz/pulse-data/recidiviz/calculator/modeling/population_projection/state/PA/mj-decrim/../../../../../../../recidiviz/calculator/modeling/population_projection/population_simulation/population_simulation_factory.py:168: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for (simulation_group_name), _ in transitions_data.groupby(disaggregation_axes):
# initialization time:  3.4161059856414795
# simulation_time:  3.3701159954071045
# WARNING:root:pretrial Warning: lower bound hit when predicting admissions.
# simulation_time:  3.3341851234436035
# 125.65669893027317
# /Users/jazz/Recidiviz/pulse-data/recidiviz/calculator/modeling/population_projection/state/PA/mj-decrim/../../../../../../../recidiviz/calculator/modeling/population_projection/super_simulation/simulator.py:288: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   simulation_results = simulation_results.groupby(

# %%
results_dict = policy_sim.upload_policy_simulation_results_to_bq(simulation_tag)
# Out:
# /Users/jazz/Recidiviz/pulse-data/recidiviz/calculator/modeling/population_projection/state/PA/mj-decrim/../../../../../../../recidiviz/calculator/modeling/population_projection/super_simulation/exporter.py:100: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   output_data["policy_simulation"]
# 100%|██████████████████████████████████████████████████████| 1/1 [00:00<00:00, 3366.22it/s]
# 100%|██████████████████████████████████████████████████████| 1/1 [00:00<00:00, 3938.31it/s]
# 100%|██████████████████████████████████████████████████████| 1/1 [00:00<00:00, 2839.75it/s]
# 100%|█████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10894.30it/s]

# %%
policy_results.groupby(["compartment", "year", "simulation_group"]).sum().loc[
    "prison", "population_difference"
].unstack("simulation_group").plot()
add_legend()

# %%
policy_results[policy_results.index >= 2020].groupby(
    ["compartment", "year", "simulation_group"]
).sum().loc["prison", "policy_total_population"].unstack("simulation_group").plot()
# Out:
# <AxesSubplot: xlabel='year'>

# %% [markdown]
# ## OTHERS

# %%
transition_dict = (
    policy_sim.validator.pop_simulations["policy"]
    .sub_simulations["20"]
    .simulation_compartments["prison"]
    .compartment_transitions.transition_tables
)

policy_ts = min(transition_dfs.keys())
for ts, transition_table in transition_dict[policy_ts].tables.items():
    #     if (policy_key != 15) & (transition_type == TransitionTableType.BEFORE):
    #         continue
    transition_table.plot()
    plt.title(f"{ts} Prison Transition Table")
    add_legend(title="Outflow To")

# %%
transition_dict = (
    policy_sim.validator.pop_simulations["policy"]
    .sub_simulations["5"]
    .simulation_compartments["prison"]
    .compartment_transitions.transition_tables
)

policy_key = max(transition_dict.keys())
for ts, transition_table in transition_dict[policy_key].tables.items():
    transition_table.plot()
    plt.title(f"{ts} Prison Transition Table")
    add_legend(title="Outflow To")
