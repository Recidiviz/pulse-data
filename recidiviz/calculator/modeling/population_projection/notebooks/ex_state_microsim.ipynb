# %%
import os
import sys
sys.path.insert(0, os.path.relpath('../..'))

from spark.super_simulation import SuperSimulation
from spark.incarceration_transitions import IncarceratedTransitions
from spark.release_transitions import ReleasedTransitions
from spark.spark_policy import SparkPolicy
import pandas as pd
from functools import partial
import yaml

# %%
test = open('../state/ex_state_microsim/ex_state_prison_model_inputs.yaml')
test_sim = SuperSimulation(test)
test_sim.simulate_baseline('pre-trial', 'prison')
# Out:
# /Users/pacopoler/.local/share/virtualenvs/recidiviz-research-LWZgHH0n/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /Users/pacopoler/.local/share/virtualenvs/recidiviz-research-LWZgHH0n/lib/python3.7/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:220: RuntimeWarning: divide by zero encountered in true_divide
#   Z_mat, R_mat, T_mat)
# initialization time:  0.7559688091278076
# simulation_time:  0.8172838687896729
# (           drug_distribution  drug_possession  theft
#  time_step
#  2013                       0                0      0
#  2014                       0                0      0
#  2015                       0                0      0
# ...

# %%
test_sim.pop_simulations['baseline'].population_projections
# Out:
#     total_population compartment time_step   simulation_group
# 1           5.000000      prison         1  drug_distribution
# 2          10.408248      prison         2  drug_distribution
# 3          16.069694      prison         3  drug_distribution
# 4          22.043224      prison         4  drug_distribution
# 5          28.306475      prison         5  drug_distribution
# 6          34.867939      prison         6  drug_distribution
# 7          34.020267      prison         7  drug_distribution
# 8          37.435714      prison         8  drug_distribution
# 9          40.358103      prison         9  drug_distribution
# 10         43.097127      prison        10  drug_distribution
# 1           0.000000     release         1  drug_distribution
# 2           0.000000     release         2  drug_distribution
# 3           0.000000     release         3  drug_distribution
# 4           0.000000     release         4  drug_distribution
# ...

# %%
test_sim.pop_simulations['baseline'].sub_simulations['drug_distribution'].simulation_compartments['prison'].transition_tables.transition_dfs
